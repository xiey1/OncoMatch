# %%
import pandas as pd
import numpy as np
import os
import pickle
from Bio import Entrez
import requests
import json
from pandas.io.json import json_normalize
from bs4 import BeautifulSoup
from collections import defaultdict

# %% [markdown]
# https://www.cancer.net/find-cancer-doctor?Distance=3&Gender=All&Languages=All&longitude=-73.956633&latitude=40.7634567&user_latitude=40.763275199999995&user_longitude=-73.9567522&user_address=1233+York+Ave%2C+New+York%2C+NY+10065%2C+USA&searchString=&search_term=1233+York+Ave%2C+New+York%2C+NY+10065%2C+USA&search_type=location&url=

# %% [markdown]
# ### Find cancer centers

# %%
search_url='https://www.cancer.net/navigating-cancer-care/cancer-basics/cancer-care-team/find-nci-designated-cancer-center'

# %%
#get html of search results page
html = requests.get(search_url).content
soup = BeautifulSoup(html,'html.parser')
## get list of cancer centers
centers = soup.find_all('h4',{'class':'field-content'})

# %%
len(centers)
# Out:
# 65

# %%
center_list=[]
for center in centers:
    center_list.append(center.get_text())

# %%
urls = soup.find_all('div',{'class':'views-field views-field-field-cps-url'})

# %%
url_list=[]
for url_sub in urls:
    url_sub2=url_sub.find_all('a')
    for url_sub3 in url_sub2:
        url_list.append(url_sub3.get('href'))

# %%
center_df=pd.DataFrame({'center_name':center_list,'center_link':url_list})
center_df=center_df.sort_values(by=['center_name'])
center_df.to_csv('cancernet_center.csv',index=False)

# %%
print(len(center_df))
# Out:
# 65

# %%
base_dir='/Volumes/Yuchen_Drive/Insight/OncoMatch'
center_df=pd.read_csv(os.path.join(base_dir, 'data/nci_center.csv'))

# %% [markdown]
# ### Combined function

# %%
def extract_oncologist_info(center_name):
    base_url = 'https://www.cancer.net/find-cancer-doctor?Distance=3&Gender=All&Languages=All&longitude=&latitude=&user_latitude=&user_longitude=&user_address=&searchString={}&search_term={}&search_type=name&url='
    center_name2 = center_name.replace(' Comprehensive Cancer Center', "")
    center_name2 = center_name2.replace(' Cancer Center', "")
    if 'Dana-Farber' in center_name2:
        center_name2='Dana-Farber'
    center_name2 = center_name2.strip().replace(" ","+")
    search_url=base_url.replace("{}",center_name2)
    
    # get html of search results page
    html = requests.get(search_url).content
    soup = BeautifulSoup(html,'html.parser')
    # get list of doctors
    doctors = soup.find_all('li',{'class':'fao-result'})
    if len(doctors)==1:
        print('No doctors have been found for {}'.format(center_name))
        return None
    if len(doctors)>1:
        print('{} doctors have been found for {}'.format(len(doctors), center_name))
    
    # extract information for each doctor
    output=defaultdict(list)
    for doc in doctors:
        ## get name of doctor
        for name in doc.find_all('a',{'class':'fao-result-name-link'}):
            output['name'].append(name.get_text()[:name.get_text().find(',')])
            output['degree'].append(name.get_text()[name.get_text().find(',')+1:])
        ## get phone number of doctor
        for phone in doc.find_all('p',{'class':'fao-result-phone'}):
            output['phone'].append(phone.get_text())
        ## get address of doctor
        for add1 in doc.find_all('p',{'class':'fao-result-address-name'}):
            output['center_name2'].append(add1.get_text())
        add2_output=""
        for add2 in doc.find_all('p',{'class':'fao-result-address-street'}):
            add2_output+=add2.get_text()
        output['address'].append(add2_output)
        for add3 in doc.find_all('p',{'class':'fao-result-address-city_state'}):
            output['city_state'].append(add3.get_text())
        ## get speciality of doctor
        for specialities in doc.find_all('div',{'class':'fao-result-specialties'}):
            sepciality_output=[]
            for speciality in specialities.find_all('p'):
                sepciality_output.append(speciality.get_text())
            output['speciality'].append(sepciality_output)
        ## get certificate of doctor
        for certificates in doc.find_all('div',{'class':'fao-result-certs'}):
            certificate_output=[]
            for certificate in certificates.find_all('p'):
                certificate_output.append(certificate.get_text())
            output['certificate'].append(certificate_output)
    data_df=pd.DataFrame.from_dict(output)
    data_df['center_name']=center_name
    return data_df

# %%
center_name=center_df.center_name.values[0]
data_df=extract_oncologist_info(center_name)
# Out:
# 13 doctors have been found for Abramson Cancer Center

# %%
center_name=center_df.center_name.values[30]
data_df=extract_oncologist_info(center_name)
# Out:
# 176 doctors have been found for Memorial Sloan-Kettering Cancer Center

# %%
def merge_oncologist_info(center_list):
    data_list=[]
    for center_name in center_list:
        data_df=extract_oncologist_info(center_name)
        if data_df is not None:
            data_list.append(data_df)
    return pd.concat(data_list)

# %%
center_df=pd.read_csv(os.path.join(base_dir, 'nci_center.csv'))
center_list=list(center_df.center_name.values)+ list(['Johns Hopkins', 'Cleveland Clinic', 'Massachusetts General Hospital'])
data_df=merge_oncologist_info(center_list)
# Out:
# 13 doctors have been found for Abramson Cancer Center
# 18 doctors have been found for Albert Einstein Cancer Center
# No doctors have been found for Alvin J. Siteman Cancer Center
# 50 doctors have been found for Arizona Cancer Center
# 16 doctors have been found for Case Comprehensive Cancer Center
# 2 doctors have been found for Chao Family Comprehensive Cancer Center
# 57 doctors have been found for City of Hope Comprehensive Cancer Center
# No doctors have been found for Cold Spring Harbor Laboratory Cancer Center
# No doctors have been found for Dan L Duncan Comprehensive Cancer Center
# 124 doctors have been found for Dana-Farber/Harvard Cancer Center
# No doctors have been found for David H. Koch Institute for Integrative Cancer Research at MIT
# 12 doctors have been found for Duke Cancer Institute
# 30 doctors have been found for Fox Chase Cancer Center
# No doctors have been found for Fred Hutchinson/University of Washington Cancer Consortium
# No doctors have been found for Fred and Pamela Buffett Cancer Center
# 7 doctors have been found for Georgetown Lombardi Comprehensive Cancer Center
# No doctors have been found for Harold C. Simmons Comprehensive Cancer Center
# No doctors have been found for Herbert Irving Comprehensive Cancer Center
# No doctors have been found for Holden Comprehensive Cancer Center
# No doctors have been found for Hollings Cancer Center
# 15 doctors have been found for Huntsman Cancer Institute
# No doctors have been found for Indiana University Melvin and Bren Simon Cancer Center
# No doctors have been found for Jonsson Comprehensive Cancer Center
# 6 doctors have been found for Knight Cancer Institute
# No doctors have been found for Laura and Isaac Perlmutter Cancer Center at NYU Langone Health
# No doctors have been found for Markey Cancer Center
# 4 doctors have been found for Masonic Cancer Center
# 6 doctors have been found for Massey Cancer Center
# 100 doctors have been found for Mayo Clinic Cancer Center
# No doctors have been found for Mays Cancer Center at UT Health San Antonio
# 176 doctors have been found for Memorial Sloan-Kettering Cancer Center
# 37 doctors have been found for Moffitt Cancer Center
# 26 doctors have been found for Moores Comprehensive Cancer Center
# No doctors have been found for Norris Cotton Cancer Center at Dartmouth
# No doctors have been found for O’Neal Comprehensive Cancer Center
# No doctors have been found for Purdue University Center for Cancer Research
# 3 doctors have been found for Robert H. Lurie Comprehensive Cancer Center
# 28 doctors have been found for Roswell Park Comprehensive Cancer Center
# 11 doctors have been found for Rutgers Cancer Institute of New Jersey
# No doctors have been found for Salk Institute Cancer Center
# No doctors have been found for Sanford Burnham Prebys Medical Discovery Institute
# 2 doctors have been found for Sidney Kimmel Cancer Center at Thomas Jefferson University
# 23 doctors have been found for Sidney Kimmel Comprehensive Cancer Center
# 19 doctors have been found for St. Jude Children's Research Hospital
# No doctors have been found for Stanford Cancer Institute (SCI)
# 7 doctors have been found for Stephenson Cancer Center
# 13 doctors have been found for Sylvester Comprehensive Cancer Center
# 14 doctors have been found for The Barbara Ann Karmanos Cancer Institute
# No doctors have been found for The Jackson Laboratory Cancer Center
# 40 doctors have been found for The Ohio State University Comprehensive Cancer Center
# 44 doctors have been found for The University of Chicago Comprehensive Cancer Center
# 25 doctors have been found for The University of Kansas Cancer Center
# 206 doctors have been found for The University of Texas MD Anderson Cancer Center
# No doctors have been found for The Wistar Institute Cancer Center
# 4 doctors have been found for Tisch Cancer Institute
# 5 doctors have been found for UC Davis Comprehensive Cancer Center
# No doctors have been found for UCSF Helen Diller Family Comprehensive Cancer Center
# No doctors have been found for UNC Lineberger Comprehensive Cancer Center
# 7 doctors have been found for UPMC Hillman Cancer Center
# 8 doctors have been found for USC Norris Comprehensive Cancer Center
# 37 doctors have been found for University of Colorado Cancer Center
# 5 doctors have been found for University of Hawaii Cancer Center
# 5 doctors have been found for University of Maryland Marlene and Stewart Greenebaum Comprehensive Cancer Center
# 4 doctors have been found for University of Michigan Rogel Cancer Center
# No doctors have been found for University of New Mexico Cancer Research and Treatment Center
# 38 doctors have been found for University of Virginia Cancer Center
# 7 doctors have been found for University of Wisconsin Carbone Cancer Center
# 5 doctors have been found for Vanderbilt-Ingram Cancer Center
# 10 doctors have been found for Wake Forest Baptist Comprehensive Cancer Center
# 14 doctors have been found for Winship Cancer Institute
# 49 doctors have been found for Yale Cancer Center
# 55 doctors have been found for Johns Hopkins
# 55 doctors have been found for Cleveland Clinic
# 59 doctors have been found for Massachusetts General Hospital

# %%
data_df.head()
# Out:
#                      name      degree                    phone  \
# 0           John H. Glick   MD, FASCO           (215) 662-6334
# 1       Arthur M. Feldman          MD           (215) 662-9801
# 2        David M. Mintzer          MD  Search for Phone Number
# 3         David J. Vaughn          MD           (215) 349-8140
# 4  Charles John Schneider    MD, FACP  Search for Phone Number
#
#                                         center_name2  \
# 0  University of Pennsylvania-Abramson Cancer Center
# 1  University of Pennsylvania-Abramson Cancer Center
# 2    Abramson Cancer Center at Pennsylvania Hospital
# 3  University of Pennsylvania-Abramson Cancer Center
# 4  Hospital of the University of Pennsylvania, Ab...
#
#                                              address  \
# 0           3400 Civic Center Blvd3rd Fl, Ste 3-300S
# 1  Penn Presbyterian Medcl Ctr51 N 39th St MAB St...
# 2                           230 W Washington Sq Fl 2
# 3            PCAM South 10-1143400 Civic Center Blvd
# 4  Pereleman Center for Advanced Medicine3400 Civ...
#
#                         city_state  \
# 0  Philadelphia, PA 19104-5127, US
# 1       Philadelphia, PA 19104, US
# 2  Philadelphia, PA 19106-3500, US
# 3       Philadelphia, PA 19104, US
# 4       Philadelphia, PA 19104, US
#
#                                           speciality  \
# 0                 [Breast Cancer, Cancer Prevention]
# 1               [Breast Cancer, Geriatrics Oncology]
# 2  [Breast Cancer, Lung Cancer, Palliative Care/E...
# 3  [Bladder Cancer, Prostate Cancer, Testicular C...
# 4  [Clinical Research, Developmental Therapeutics...
#
#                                          certificate              center_name
# 0              [Internal Medicine, Medical Oncology]  Abramson Cancer Center
# 1              [Internal Medicine, Medical Oncology]  Abramson Cancer Center
# 2  [Hematology, Hospice and Palliative Medicine, ...  Abramson Cancer Center
# 3                                 [Medical Oncology]  Abramson Cancer Center
# 4                                 [Medical Oncology]  Abramson Cancer Center

# %%
data_df.shape
# Out:
# (1501, 9)

# %%
print('{} oncologists have been found in cancernet'.format(data_df.name.nunique()))
# Out:
# 1470 oncologists have been found in cancernet

# %%
data_df.query("name=='William Wong'")
# Out:
#             name degree                    phone         center_name2  \
# 24  William Wong     MD  Search for Phone Number  MAYO CLINIC Arizona
# 85  William Wong     MD  Search for Phone Number  MAYO CLINIC Arizona
#
#               address                     city_state  \
# 24  13400 E Shea Blvd  Scottsdale, AZ 85259-5404, US
# 85  13400 E Shea Blvd  Scottsdale, AZ 85259-5404, US
#
#                             speciality  \
# 24  [Breast Cancer, Clinical Research]
# 85  [Breast Cancer, Clinical Research]
#
#                                           certificate  \
# 24  [Internal Medicine, Pharmacy, Radiation Oncology]
# 85  [Internal Medicine, Pharmacy, Radiation Oncology]
#
#                   center_name
# 24      Arizona Cancer Center
# 85  Mayo Clinic Cancer Center

# %%
data_df=data_df[-data_df.name.duplicated()]
print(data_df.shape)
# Out:
# (1470, 9)

# %%
pickle.dump(data_df, open(os.path.join(base_dir, "data/Oncologist_info_1470.pkl"), "wb"))

# %%
data_df=pickle.load(open(os.path.join(base_dir, "data/Oncologist_info_1470.pkl"),"rb"))

# %%
data_df.to_csv(os.path.join(base_dir, "data/Oncologist_info_1470.csv"), index=False)

# %%
data_df=pd.read_csv(os.path.join(base_dir, "data/Oncologist_info_1470.csv"),index_col='name')

# %%
data_df.shape
# Out:
# (1470, 9)

# %%
data_df.head()
# Out:
#                             degree                    phone  \
# name
# John H. Glick            MD, FASCO           (215) 662-6334
# Arthur M. Feldman               MD           (215) 662-9801
# David M. Mintzer                MD  Search for Phone Number
# David J. Vaughn                 MD           (215) 349-8140
# Charles John Schneider    MD, FACP  Search for Phone Number
#
#                                                              center_name2  \
# name
# John H. Glick           University of Pennsylvania-Abramson Cancer Center
# Arthur M. Feldman       University of Pennsylvania-Abramson Cancer Center
# David M. Mintzer          Abramson Cancer Center at Pennsylvania Hospital
# David J. Vaughn         University of Pennsylvania-Abramson Cancer Center
# Charles John Schneider  Hospital of the University of Pennsylvania, Ab...
#
#                                                                   address  \
# name
# John H. Glick                    3400 Civic Center Blvd3rd Fl, Ste 3-300S
# Arthur M. Feldman       Penn Presbyterian Medcl Ctr51 N 39th St MAB St...
# David M. Mintzer                                 230 W Washington Sq Fl 2
# David J. Vaughn                   PCAM South 10-1143400 Civic Center Blvd
# Charles John Schneider  Pereleman Center for Advanced Medicine3400 Civ...
#
#                                              city_state  \
# name
# John H. Glick           Philadelphia, PA 19104-5127, US
# Arthur M. Feldman            Philadelphia, PA 19104, US
# David M. Mintzer        Philadelphia, PA 19106-3500, US
# David J. Vaughn              Philadelphia, PA 19104, US
# Charles John Schneider       Philadelphia, PA 19104, US
#
#                                                                speciality  \
# name
# John H. Glick                      ['Breast Cancer', 'Cancer Prevention']
# Arthur M. Feldman                ['Breast Cancer', 'Geriatrics Oncology']
# David M. Mintzer        ['Breast Cancer', 'Lung Cancer', 'Palliative C...
# David J. Vaughn         ['Bladder Cancer', 'Prostate Cancer', 'Testicu...
# Charles John Schneider  ['Clinical Research', 'Developmental Therapeut...
#
#                                                               certificate  \
# name
# John H. Glick                   ['Internal Medicine', 'Medical Oncology']
# Arthur M. Feldman               ['Internal Medicine', 'Medical Oncology']
# David M. Mintzer        ['Hematology', 'Hospice and Palliative Medicin...
# David J. Vaughn                                      ['Medical Oncology']
# Charles John Schneider                               ['Medical Oncology']
#
#                                     center_name  article_num
# name
# John H. Glick           Abramson Cancer Center             7
# Arthur M. Feldman       Abramson Cancer Center             0
# David M. Mintzer        Abramson Cancer Center            13
# David J. Vaughn         Abramson Cancer Center            86
# Charles John Schneider  Abramson Cancer Center             0

# %%
doctor2pmid_1153_dict_df=pd.read_csv(os.path.join(base_dir, 'data/doctor2pmid_1153_dict_df.csv'),converters={"Condition":'pmid'})

# %%
data_df_1153 = data_df.loc[np.array(doctor2pmid_1153_dict_df.name)]

# %%
data_df_1153.head()
# Out:
#                                  degree                    phone  \
# name
# John H. Glick                 MD, FASCO           (215) 662-6334
# David M. Mintzer                     MD  Search for Phone Number
# David J. Vaughn                      MD           (215) 349-8140
# Marcia S. Brose          MD, PhD, FASCO           (215) 615-0741
# Robert G. Maki     MD, PhD, FACP, FASCO             800-789-7366
#
#                                                        center_name2  \
# name
# John H. Glick     University of Pennsylvania-Abramson Cancer Center
# David M. Mintzer    Abramson Cancer Center at Pennsylvania Hospital
# David J. Vaughn   University of Pennsylvania-Abramson Cancer Center
# Marcia S. Brose   University of Pennsylvania-Abramson Cancer Center
# Robert G. Maki                               Abramson Cancer Center
#
#                                                             address  \
# name
# John H. Glick              3400 Civic Center Blvd3rd Fl, Ste 3-300S
# David M. Mintzer                           230 W Washington Sq Fl 2
# David J. Vaughn             PCAM South 10-1143400 Civic Center Blvd
# Marcia S. Brose                         5 Silverstein3400 Spruce St
# Robert G. Maki    Perelman Center for Advanced Medicine3400 Civi...
#
#                                         city_state  \
# name
# John H. Glick      Philadelphia, PA 19104-5127, US
# David M. Mintzer   Philadelphia, PA 19106-3500, US
# David J. Vaughn         Philadelphia, PA 19104, US
# Marcia S. Brose         Philadelphia, PA 19104, US
# Robert G. Maki    Philadelphia, Pennsylvania 19104
#
#                                                          speciality  \
# name
# John H. Glick                ['Breast Cancer', 'Cancer Prevention']
# David M. Mintzer  ['Breast Cancer', 'Lung Cancer', 'Palliative C...
# David J. Vaughn   ['Bladder Cancer', 'Prostate Cancer', 'Testicu...
# Marcia S. Brose   ['Head and Neck Cancer', 'Clinical Research', ...
# Robert G. Maki    ['Bone Cancer', 'Sarcoma', 'Clinical Trials/Bi...
#
#                                                         certificate  \
# name
# John H. Glick             ['Internal Medicine', 'Medical Oncology']
# David M. Mintzer  ['Hematology', 'Hospice and Palliative Medicin...
# David J. Vaughn                                ['Medical Oncology']
# Marcia S. Brose           ['Internal Medicine', 'Medical Oncology']
# Robert G. Maki            ['Internal Medicine', 'Medical Oncology']
#
#                               center_name  article_num
# name
# John H. Glick     Abramson Cancer Center             7
# David M. Mintzer  Abramson Cancer Center            13
# David J. Vaughn   Abramson Cancer Center            86
# Marcia S. Brose   Abramson Cancer Center            50
# Robert G. Maki    Abramson Cancer Center           162

# %%
data_df_1153.center_name.value_counts().to_frame().reset_index().rename(columns={'center_name':'counts', 'index':'center_name'})
# Out:
#                                           center_name  counts
# 0   The University of Texas MD Anderson Cancer Center     179
# 1              Memorial Sloan-Kettering Cancer Center     141
# 2                   Dana-Farber/Harvard Cancer Center     104
# 3                           Mayo Clinic Cancer Center      70
# 4                      Massachusetts General Hospital      49
# 5            City of Hope Comprehensive Cancer Center      43
# 6                                    Cleveland Clinic      42
# 7                                  Yale Cancer Center      40
# 8                                       Johns Hopkins      34
# 9   The University of Chicago Comprehensive Cancer...      33
# 10                              Moffitt Cancer Center      32
# 11  The Ohio State University Comprehensive Cancer...      30
# 12                              Arizona Cancer Center      30
# 13           Roswell Park Comprehensive Cancer Center      26
# 14               University of Colorado Cancer Center      25
# 15               University of Virginia Cancer Center      24
# 16                            Fox Chase Cancer Center      23
# 17          Sidney Kimmel Comprehensive Cancer Center      19
# 18              St. Jude Children's Research Hospital      17
# 19             The University of Kansas Cancer Center      16
# 20                 Moores Comprehensive Cancer Center      15
# 21                          Huntsman Cancer Institute      13
# 22                      Albert Einstein Cancer Center      12
# 23                   Case Comprehensive Cancer Center      11
# 24          The Barbara Ann Karmanos Cancer Institute      10
# 25                           Winship Cancer Institute      10
# 26                            Abramson Cancer Center        9
# 27              Sylvester Comprehensive Cancer Center       9
# 28             Rutgers Cancer Institute of New Jersey       8
# 29    Wake Forest Baptist Comprehensive Cancer Center       8
# 30                              Duke Cancer Institute       7
# 31    Georgetown Lombardi Comprehensive Cancer Center       6
# 32             USC Norris Comprehensive Cancer Center       6
# 33                         UPMC Hillman Cancer Center       5
# 34      University of Wisconsin Carbone Cancer Center       5
# 35  University of Maryland Marlene and Stewart Gre...       4
# 36                             Tisch Cancer Institute       4
# 37                    Vanderbilt-Ingram Cancer Center       4
# 38               UC Davis Comprehensive Cancer Center       4
# 39                            Knight Cancer Institute       4
# 40        Robert H. Lurie Comprehensive Cancer Center       3
# 41         University of Michigan Rogel Cancer Center       3
# 42                 University of Hawaii Cancer Center       3
# 43                               Massey Cancer Center       3
# 44                              Masonic Cancer Center       3
# 45                           Stephenson Cancer Center       3
# 46            Chao Family Comprehensive Cancer Center       2
# 47  Sidney Kimmel Cancer Center at Thomas Jefferso...       2

# %%
data_df_1153.to_csv(os.path.join(base_dir, "data/Oncologist_info_1153.csv"),index=True,index_label='name')

# %%
onco_df=pd.read_csv(os.path.join(base_dir, "data/Oncologist_info_1153.csv"), index_col='name')

# %%
onco_df.shape
# Out:
# (1153, 9)

# %%
onco_df.head()
# Out:
#                                  degree                    phone  \
# name
# John H. Glick                 MD, FASCO           (215) 662-6334
# David M. Mintzer                     MD  Search for Phone Number
# David J. Vaughn                      MD           (215) 349-8140
# Marcia S. Brose          MD, PhD, FASCO           (215) 615-0741
# Robert G. Maki     MD, PhD, FACP, FASCO             800-789-7366
#
#                                                        center_name2  \
# name
# John H. Glick     University of Pennsylvania-Abramson Cancer Center
# David M. Mintzer    Abramson Cancer Center at Pennsylvania Hospital
# David J. Vaughn   University of Pennsylvania-Abramson Cancer Center
# Marcia S. Brose   University of Pennsylvania-Abramson Cancer Center
# Robert G. Maki                               Abramson Cancer Center
#
#                                                             address  \
# name
# John H. Glick              3400 Civic Center Blvd3rd Fl, Ste 3-300S
# David M. Mintzer                           230 W Washington Sq Fl 2
# David J. Vaughn             PCAM South 10-1143400 Civic Center Blvd
# Marcia S. Brose                         5 Silverstein3400 Spruce St
# Robert G. Maki    Perelman Center for Advanced Medicine3400 Civi...
#
#                                         city_state  \
# name
# John H. Glick      Philadelphia, PA 19104-5127, US
# David M. Mintzer   Philadelphia, PA 19106-3500, US
# David J. Vaughn         Philadelphia, PA 19104, US
# Marcia S. Brose         Philadelphia, PA 19104, US
# Robert G. Maki    Philadelphia, Pennsylvania 19104
#
#                                                          speciality  \
# name
# John H. Glick                ['Breast Cancer', 'Cancer Prevention']
# David M. Mintzer  ['Breast Cancer', 'Lung Cancer', 'Palliative C...
# David J. Vaughn   ['Bladder Cancer', 'Prostate Cancer', 'Testicu...
# Marcia S. Brose   ['Head and Neck Cancer', 'Clinical Research', ...
# Robert G. Maki    ['Bone Cancer', 'Sarcoma', 'Clinical Trials/Bi...
#
#                                                         certificate  \
# name
# John H. Glick             ['Internal Medicine', 'Medical Oncology']
# David M. Mintzer  ['Hematology', 'Hospice and Palliative Medicin...
# David J. Vaughn                                ['Medical Oncology']
# Marcia S. Brose           ['Internal Medicine', 'Medical Oncology']
# Robert G. Maki            ['Internal Medicine', 'Medical Oncology']
#
#                               center_name  article_num
# name
# John H. Glick     Abramson Cancer Center             7
# David M. Mintzer  Abramson Cancer Center            13
# David J. Vaughn   Abramson Cancer Center            86
# Marcia S. Brose   Abramson Cancer Center            50
# Robert G. Maki    Abramson Cancer Center           162
