# %%
from flask import render_template
from flask import request
import pandas as pd
import numpy as np
import os
import gensim
from nltk.stem import WordNetLemmatizer
import pickle
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict
from ast import literal_eval

# %%
base_dir='/Volumes/Yuchen_Drive/Insight/OncoMatch'
abstract_catalog=pd.read_csv(os.path.join(base_dir,'data/abstract_citation_annot_df_50930.csv'),index_col='pmid')
cancertype_df=pd.read_csv(os.path.join(base_dir, "data/cancerty_df2.csv"))
gene_df=pd.read_csv(os.path.join(base_dir, "data/HGNC_df2.csv"))
pmid2doctor_dict=pickle.load(open(os.path.join(base_dir, "data/pmid2doctor_dict.pkl"),"rb"))
cancer2pmid_dict=pickle.load(open(os.path.join(base_dir, "data/cancer2pmid_dict.pkl"),"rb"))
doctor2clinical_dict2=pickle.load(open(os.path.join(base_dir, "data/doctor2clinical_dict2.pkl"),"rb"))
doctor2clinical_dict2_df=pd.read_csv(os.path.join(base_dir, 'data/doctor2clinical_dict2_df.csv'),index_col='name')
onco_df=pickle.load(open(os.path.join(base_dir, "data/Oncologist_info_clinicaltrial_1470.pkl"),"rb"))
onco_df.index=onco_df.name
cancertype_list=list(cancertype_df.cancer_type.sort_values().unique())

# %%
cancertype_df.head()
# Out:
#        pmid                         cancer_type
# 0  10079468                            Leukemia
# 1  10079468  Chronic Myelogenous Leukemia (CML)
# 2  10581602                     Prostate Cancer
# 3  10581602                         Bone Cancer
# 4  11719088                   Pancreatic Cancer

# %%
gene_df.head()
# Out:
#        pmid   HGNC
# 0  10037348  DNMT1
# 1  10079468    BCR
# 2  10079468   ABL1
# 3  10873802   AKT1
# 4  11050493  DNMT1

# %%
gene_list=list(gene_df.HGNC.unique())

# %%
print(len(gene_list))
# Out:
# 205

# %%
cancer_type='Breast Cancer'
prefix="_".join(i.lower() for i in cancer_type.split())

# %%
cancerclinical2doctor_dict_df=pd.read_csv(os.path.join(base_dir, 'data/cancerclinical2doctor_dict_df.csv'),converters={"doctor":literal_eval},index_col='cancer_type')

# %%
len(cancerclinical2doctor_dict_df)
# Out:
# 53

# %%
cancerclinical2doctor_dict_df.head()
# Out:
#                                                               doctor
# cancer_type
# Breast Cancer      [Abenaa M. Brewster, Adam Brufsky, Aditya Bard...
# Lung Cancer        [Abhimanyu Ghose, Adam Brufsky, Aditya Bardia,...
# Leukemia           [Aaron Rapoport, Abdulraheem Yacoub, Abhinav D...
# Prostate Cancer    [Abhishek A Solanki, Adam Brufsky, Aditya Bard...
# Colorectal Cancer  [Adam Brufsky, Alok A. Khorana, Ana Maria Lope...

# %%
class Oncomatch_model():
    def __init__(self,cancer_type):
        self.base_dir='/Volumes/Yuchen_Drive/Insight/OncoMatch'
        self.cancer_type=cancer_type
        self.prefix="_".join(i.lower() for i in cancer_type.split())
        self.bow_dict=gensim.corpora.Dictionary.load(os.path.join(self.base_dir,'models_lda/{}_abstract_bow_dict.dict'.format(self.prefix)))
        self.tfidf=gensim.models.TfidfModel.load(os.path.join(self.base_dir,'models_lda/{}_abstract_tfidf.tfidf'.format(self.prefix)))
        self.lda_model=gensim.models.LdaMulticore.load(os.path.join(self.base_dir,'models_lda/{}_abstract_lda.lda'.format(self.prefix)))
        self.lda_df=pd.read_csv(os.path.join(self.base_dir, "models_lda/{}_abstract_ldavector_df.csv".format(self.prefix)), index_col='pmid').drop(['pred'],axis=1)
        self.stop_words=pickle.load(open(os.path.join(self.base_dir, "data/stop_words_lda.set"),"rb"))
        
        #self.onco_df=pickle.load(open(os.path.join(base_dir, "data/Oncologist_info_clinicaltrial_1470.pkl"),"rb"))
        self.onco_df=pd.read_csv(os.path.join(self.base_dir, "data/Oncologist_info_clinicaltrial_1470.csv"))
        self.onco_df.index=self.onco_df.name
        #self.cancerclinical2doctor_dict=pickle.load(open(os.path.join(base_dir, "data/cancerclinical2doctor_dict.pkl"),"rb"))
        self.cancerclinical2doctor_dict_df=pd.read_csv(os.path.join(self.base_dir, 'data/cancerclinical2doctor_dict_df.csv'),converters={"doctor":literal_eval},index_col='cancer_type')
        #self.doctor2clinical_dict2=pickle.load(open(os.path.join(base_dir, "data/doctor2clinical_dict2.pkl"),"rb"))
        self.doctor2clinical_dict2_df=pd.read_csv(os.path.join(self.base_dir, 'data/doctor2clinical_dict2_df.csv'),index_col='name')
        #self.pmid2doctor_dict=pickle.load(open(os.path.join(base_dir, "data/pmid2doctor_dict.pkl"),"rb"))
        self.pmid2doctor_dict_df=pd.read_csv(os.path.join(self.base_dir, 'data/pmid2doctor_dict_df.csv'),converters={"doctor":literal_eval},index_col='pmid')
        #self.word2vec = gensim.models.Word2Vec.load(os.path.join(base_dir, 'models_w2v/doctor_recommendation_w2vmodel_dim300_mincount2.w2v'))
        #self.doc2vec=gensim.models.Doc2Vec.load(os.path.join(base_dir, 'preprocessing/personalized_medicine_d2vmodel_dim100_v2.d2v'))
        #self.lsa_model=gensim.models.LsiModel.load(os.path.join(base_dir,'preprocessing/Personalized_Medicine_lsimodel'))
        #self.lsa_df=pickle.load(open(os.path.join(base_dir,"preprocessing/Personalized_Medicine_train_lsavector_df.pkl"),"rb")).drop(['pred','class'],axis=1)
        #self.doctovec_df=pickle.load(open(os.path.join(base_dir,"preprocessing/Personalized_Medicine_train_doctovec_df.pkl"),"rb"))

    def preprocess(self, text):
        result = []
        for token in gensim.utils.simple_preprocess(text):
            temp=WordNetLemmatizer().lemmatize(token).lower()
            if len(temp)>1 and temp not in self.stop_words:
                result.append(temp)
        return result

    def get_embedding_vector(self, text):
        text_corpus=[self.bow_dict.doc2bow(text)]
        text_tfidf=self.tfidf[text_corpus]

        #text_lsa=self.lsa_model[text_tfidf]
        #text_lsa=gensim.matutils.corpus2csc(text_lsa)
        #text_lsa=text_lsa.T.toarray()

        text_lda=self.lda_model[text_tfidf]
        text_lda = gensim.matutils.corpus2csc(text_lda)
        text_lda = text_lda.T.toarray()

        #text_doc2vec=self.doc2vec.infer_vector(text, alpha=0.001, min_alpha=0.001, steps=10000)
        #text_doc2vec=text_doc2vec.reshape(1,-1)

        return text_lda

    def compute_similarity(self, embedding_matrix, text_vector):
        return cosine_similarity(X=embedding_matrix,Y=text_vector,dense_output=False)

    def get_similarity_scores(self, text):
        text_preprocess=self.preprocess(text)
        text_lda=self.get_embedding_vector(text_preprocess)

        #text_lsa_sim=self.compute_similarity(self.lsa_df,text_lsa)
        text_lda_sim=self.compute_similarity(self.lda_df,text_lda)
        #text_doc2vec_sim=self.compute_similarity(self.doctovec_df,text_doc2vec)

        similarity_df=pd.DataFrame({'pmid':self.lda_df.index, 'lda_similarity':text_lda_sim.squeeze()}).sort_values(by=['lda_similarity'],ascending=False).reset_index().drop(['index'],axis=1)
        return similarity_df
    
    def get_onco_info(self, pmid_list,clinical_trial):
        """
        Input: cancer_type and a list of pmid
        Output: DataFrame containing information for oncologists that publish the articles
        """
        onco2pmid=defaultdict(list)
        onco2rank=defaultdict(list)
        for i,pmid in enumerate(pmid_list):
            for doctor in self.pmid2doctor_dict_df.loc[pmid,'doctor']:
                onco2pmid[doctor].append(pmid)
                onco2rank[doctor].append(i)
        temp_df = self.onco_df.loc[np.array(list(onco2pmid.keys()))]
        temp_df['query_pmid'] = temp_df.name.apply(lambda x:onco2pmid[x])
        temp_df['query_pmid_num'] = temp_df.name.apply(lambda x:len(onco2pmid[x]))
        temp_df['pmid_rank'] = temp_df.name.apply(lambda x:onco2rank[x])
        temp_df['pmid_rank_10th_percentile'] = temp_df.pmid_rank.apply(lambda x: sum(np.array(x)<=int(np.ceil(temp_df.shape[0]/10))))
    
        if clinical_trial and self.cancer_type in self.cancerclinical2doctor_dict_df.index:
            doctor_clin = np.intersect1d(np.array(self.cancerclinical2doctor_dict_df.loc[self.cancer_type,'doctor']), temp_df.name.values)
            temp_df = temp_df.loc[np.array(doctor_clin)].sort_values(by=['pmid_rank_10th_percentile'],ascending=False)
            temp_df['clinical_trial_num2']=temp_df.name.apply(lambda x: int(self.doctor2clinical_dict2_df.loc[x, self.cancer_type]))
    
        return temp_df

    def get_clinical_data(self, onco_name):
        cancer_prefix="_".join(i.lower() for i in self.cancer_type.split())
        temp_df = pd.read_csv(os.path.join(self.base_dir, 'clinical_trial/{}_clinical_trial_info.csv'.format(cancer_prefix)))
        temp_df_onco=temp_df.query('name=="{}"'.format(onco_name))
        return temp_df_onco

# %%
class Oncomatch_model():
    def __init__(self,cancer_type):
        self.base_dir='/Volumes/Yuchen_Drive/Insight/OncoMatch'
        self.cancer_type=cancer_type
        self.prefix="_".join(i.lower() for i in cancer_type.split())
        self.bow_dict=gensim.corpora.Dictionary.load(os.path.join(self.base_dir,'models_lda/{}_abstract_bow_dict.dict'.format(self.prefix)))
        self.tfidf=gensim.models.TfidfModel.load(os.path.join(self.base_dir,'models_lda/{}_abstract_tfidf.tfidf'.format(self.prefix)))
        self.lda_model=gensim.models.LdaMulticore.load(os.path.join(self.base_dir,'models_lda/{}_abstract_lda.lda'.format(self.prefix)))
        self.lda_df=pd.read_csv(os.path.join(self.base_dir, "models_lda/{}_abstract_ldavector_df.csv".format(self.prefix)), index_col='pmid').drop(['pred'],axis=1)
        self.stop_words=pickle.load(open(os.path.join(self.base_dir, "data/stop_words_lda.set"),"rb"))

        self.onco_df=pickle.load(open(os.path.join(self.base_dir, "data/Oncologist_info_clinicaltrial_1470.pkl"),"rb"))
        self.onco_df.index=self.onco_df.name
        self.cancerclinical2doctor_dict=pickle.load(open(os.path.join(self.base_dir, "data/cancerclinical2doctor_dict.pkl"),"rb"))
        #self.doctor2clinical_dict2_df=pd.read_csv(os.path.join(base_dir, 'data/doctor2clinical_dict2_df.csv'),index_col='name')
        self.doctor2clinical_dict2=pickle.load(open(os.path.join(self.base_dir, "data/doctor2clinical_dict2.pkl"),"rb"))
        self.pmid2doctor_dict=pickle.load(open(os.path.join(self.base_dir, "data/pmid2doctor_dict.pkl"),"rb"))
        #self.word2vec = gensim.models.Word2Vec.load(os.path.join(base_dir, 'models_w2v/doctor_recommendation_w2vmodel_dim300_mincount2.w2v'))
        #self.doc2vec=gensim.models.Doc2Vec.load(os.path.join(base_dir, 'preprocessing/personalized_medicine_d2vmodel_dim100_v2.d2v'))
        #self.lsa_model=gensim.models.LsiModel.load(os.path.join(base_dir,'preprocessing/Personalized_Medicine_lsimodel'))
        #self.lsa_df=pickle.load(open(os.path.join(base_dir,"preprocessing/Personalized_Medicine_train_lsavector_df.pkl"),"rb")).drop(['pred','class'],axis=1)
        #self.doctovec_df=pickle.load(open(os.path.join(base_dir,"preprocessing/Personalized_Medicine_train_doctovec_df.pkl"),"rb"))

    def preprocess(self, text):
        result = []
        for token in gensim.utils.simple_preprocess(text):
            temp=WordNetLemmatizer().lemmatize(token).lower()
            if len(temp)>1 and temp not in self.stop_words:
                result.append(temp)
        return result

    def get_embedding_vector(self, text):
        text_corpus=[self.bow_dict.doc2bow(text)]
        text_tfidf=self.tfidf[text_corpus]

        #text_lsa=self.lsa_model[text_tfidf]
        #text_lsa=gensim.matutils.corpus2csc(text_lsa)
        #text_lsa=text_lsa.T.toarray()

        text_lda=self.lda_model[text_tfidf]
        text_lda = gensim.matutils.corpus2csc(text_lda)
        text_lda = text_lda.T.toarray()

        #text_doc2vec=self.doc2vec.infer_vector(text, alpha=0.001, min_alpha=0.001, steps=10000)
        #text_doc2vec=text_doc2vec.reshape(1,-1)

        return text_lda

    def compute_similarity(self, embedding_matrix, text_vector):
        return cosine_similarity(X=embedding_matrix,Y=text_vector,dense_output=False)

    def get_similarity_scores(self, text):
        text_preprocess=self.preprocess(text)
        text_lda=self.get_embedding_vector(text_preprocess)

        #text_lsa_sim=self.compute_similarity(self.lsa_df,text_lsa)
        text_lda_sim=self.compute_similarity(self.lda_df,text_lda)
        #text_doc2vec_sim=self.compute_similarity(self.doctovec_df,text_doc2vec)

        similarity_df=pd.DataFrame({'pmid':self.lda_df.index, 'lda_similarity':text_lda_sim.squeeze()}).sort_values(by=['lda_similarity'],ascending=False).reset_index().drop(['index'],axis=1)
        return similarity_df

    def get_onco_info(self, pmid_list,clinical_trial):
        """
        Input: cancer_type and a list of pmid
        Output: DataFrame containing information for oncologists that publish the articles
        """
        onco2pmid=defaultdict(list)
        onco2rank=defaultdict(list)
        for i,pmid in enumerate(pmid_list):
            for doctor in self.pmid2doctor_dict[pmid]:
                onco2pmid[doctor].append(pmid)
                onco2rank[doctor].append(i)
        temp_df = self.onco_df.loc[np.array(list(onco2pmid.keys()))]
        temp_df['query_pmid'] = temp_df.name.apply(lambda x:onco2pmid[x])
        temp_df['query_pmid_num'] = temp_df.name.apply(lambda x:len(onco2pmid[x]))
        temp_df['pmid_rank'] = temp_df.name.apply(lambda x:onco2rank[x])
        temp_df['pmid_rank_10th_percentile'] = temp_df.pmid_rank.apply(lambda x: sum(np.array(x)<=int(np.ceil(temp_df.shape[0]/10))))

        if clinical_trial and self.cancer_type in self.cancerclinical2doctor_dict:
            doctor_clin = np.intersect1d(np.array(self.cancerclinical2doctor_dict[self.cancer_type]), temp_df.name.values)
            temp_df = temp_df.loc[np.array(doctor_clin)].sort_values(by=['pmid_rank_10th_percentile'],ascending=False)
            temp_df['clinical_trial_num2']=temp_df.name.apply(lambda x: self.doctor2clinical_dict2[x][self.cancer_type])

        return temp_df

    def get_clinical_data(self, onco_name):
        cancer_prefix="_".join(i.lower() for i in self.cancer_type.split())
        temp_df = pd.read_csv(os.path.join(self.base_dir, 'clinical_trial/{}_clinical_trial_info.csv'.format(cancer_prefix)))
        temp_df_onco=temp_df.query('name=="{}"'.format(onco_name))
        return temp_df_onco

# %%
class Get_info():
    def __init__(self):
        base_dir='/Volumes/Yuchen_Drive/Insight/OncoMatch'
        #self.doctor2pmid_dict=pickle.load(open(os.path.join(base_dir, "data/doctor2pmid_1153_dict.pkl"),"rb"))
        self.cancer2pmid_dict=pickle.load(open(os.path.join(base_dir, "data/cancer2pmid_dict.pkl"),"rb"))
        self.cancer2doctor_dict=pickle.load(open(os.path.join(base_dir, "data/cancer2doctor_dict.pkl"),"rb"))
        self.pmid2doctor_dict=pickle.load(open(os.path.join(base_dir, "data/pmid2doctor_dict.pkl"),"rb"))
        self.pmid2cancer_dict=pickle.load(open(os.path.join(base_dir, "data/pmid2doctor_dict.pkl"),"rb"))
        self.doctor2cancer_dict=pickle.load(open(os.path.join(base_dir, "data/doctor2cancer_dict.pkl"),"rb"))

    def gene_to_pmid(self,gene,data):
        pmid_array = data.query('HGNC=="{}"'.format(gene)).pmid.unique()
        return pmid_array
    
    #def doctor_to_pmid(self,doctor):
    #    return self.doctor2pmid_dict[doctor]
    
    def cancer_to_pmid(self,cancer):
        return self.cancer2pmid_dict[cancer]
    
    def cancer_to_doctor(self,cancer):
        return self.cancer2doctor_dict[cancer]
    
    def pmid_to_doctor(self,pmid):
        return self.pmid2doctor_dict[pmid]
    
    def pmid_to_cancer(self,pmid):
        return self.pmid2cancer_dict[pmid]
    
    def doctor_to_cancer(self,doctor):
        return self.doctor2cancer_dict[doctor]

# %%
def get_onco_info(cancer_type, pmid_list,clinical_trial):
    """
    Input: cancer_type and a list of pmid
    Output: DataFrame containing information for oncologists that publish the articles
    """
    onco2pmid=defaultdict(list)
    onco2rank=defaultdict(list)
    for i,pmid in enumerate(pmid_list):
        for doctor in pmid2doctor_dict[pmid]:
            onco2pmid[doctor].append(pmid)
            onco2rank[doctor].append(i)
    temp_df = onco_df.loc[np.array(list(onco2pmid.keys()))]
    temp_df['query_pmid'] = temp_df.name.apply(lambda x:onco2pmid[x])
    temp_df['query_pmid_num'] = temp_df.name.apply(lambda x:len(onco2pmid[x]))
    temp_df['pmid_rank'] = temp_df.name.apply(lambda x:onco2rank[x])
    temp_df['pmid_rank_10th_percentile'] = temp_df.pmid_rank.apply(lambda x: sum(np.array(x)<=int(np.ceil(temp_df.shape[0]/10))))
    
    if clinical_trial and cancer_type in cancerclinical2doctor_dict:
        doctor_clin = np.intersect1d(np.array(cancerclinical2doctor_dict[cancer_type]), temp_df.name)
        temp_df = temp_df.loc[np.array(doctor_clin)].sort_values(by=['pmid_rank_10th_percentile'],ascending=False)
        temp_df['clinical_trial_{}_num'.format(cancer_type)]=temp_df.name.apply(lambda x: doctor2clinical_dict2[x][cancer_type])
        temp_df.head()
    
    return temp_df

# %%
cancer_type='Breast Cancer'
original_text = 'The patient is looking for therapies for breast cancer'
onco=Oncomatch_model(cancer_type)
similarity_df=onco.get_similarity_scores(original_text)   ## (8563, 2)

# %%
## Gene filtering
gene_name = 'NA'
if gene_name != 'NA':
    pmid_gene=Get_info().gene_to_pmid(gene_name, gene_df)
    pmid_list=[]
    for i in similarity_df.pmid:
        if i in pmid_gene:
            pmid_list.append(i)
else:
    pmid_list=list(similarity_df.pmid)   ## 865

# %%
## clinical trial filtering and get oncologist info
clinical_trial = False
test_df = onco.get_onco_info(pmid_list,clinical_trial)   ## (95, 16)

# %%
test_df.sort_values(by=['query_pmid_num'],ascending=False)
# Out:
#                                             name  \
# name
# Gabriel N. Hortobagyi      Gabriel N. Hortobagyi
# Kelly Hunt                            Kelly Hunt
# Fergus Couch                        Fergus Couch
# Monica Morrow                      Monica Morrow
# Lajos Pusztai                      Lajos Pusztai
# Funda Meric-Bernstam        Funda Meric-Bernstam
# Eric P. Winer                      Eric P. Winer
# Edith A. Perez                    Edith A. Perez
# Vicente Valero                    Vicente Valero
# Banu Arun                              Banu Arun
# Naoto T. Ueno                      Naoto T. Ueno
# Claudine Isaacs                  Claudine Isaacs
# Larry Norton                        Larry Norton
# Kenneth Offit                      Kenneth Offit
# Elizabeth A. Mittendorf  Elizabeth A. Mittendorf
# Adam Brufsky                        Adam Brufsky
# Antonio C. Wolff                Antonio C. Wolff
# Amy C. Degnim                      Amy C. Degnim
# Stephen B. Edge                  Stephen B. Edge
# Vered Stearns                      Vered Stearns
# Sharon H. Giordano            Sharon H. Giordano
# Ann H. Partridge                Ann H. Partridge
# Charis Eng                            Charis Eng
# Isabelle Bedrosian            Isabelle Bedrosian
# Anthony Lucci                      Anthony Lucci
# Harold J. Burstein            Harold J. Burstein
# Saundra S. Buys                  Saundra S. Buys
# Debu Tripathy                      Debu Tripathy
# Anees B. Chagpar                Anees B. Chagpar
# Paul E. Goss                        Paul E. Goss
# ...                                          ...
# Milind M. Javle                  Milind M. Javle
# Rachna T. Shroff                Rachna T. Shroff
# Michael P. La Quaglia      Michael P. La Quaglia
# Nikhil I. Khushalani               Tampa, FL 33612-9416, US
# Amod Sarnaik                       Tampa, FL 33612-9416, US
# Lisa Diamond             MANHASSET, New York 11030-2419, US
# Susan Anitra Melin         Winston Salem, NC 27157-1082, US
# Gary C. Doolittle            Kansas City, KS 66160-0001, US
# Ryan D. Gentzler         Charlottesville, VA 22908-0716, US
# Mary Helen Hackney                   Richmond, VA 23298, US
# Jill N. Allen                          Boston, MA 02114, US
# Sandip Pravin Patel             La Jolla, CA 92093-1503, US
# Philip Agop Philip               Detroit, MI 48201-2013, US
# Jerome Ritz                       Boston, MA 02215-5418, US
# Rachel N. Grisham                   New York , NY 10065, US
# William R. Jarnagin                  New York, NY 10021, US
# Ellis Glenn Levine               Buffalo, NY 14263-0001, US
# Valerie Klairisa Reed                 Houston, TX 77030, US
# Abdulraheem Yacoub              Westwood, KS 66205-2005, US
# Yanis Boumber                    Philadelphia, PA 19111, US
#
#                                                                 speciality  \
# name
# Gabriel N. Hortobagyi    ['Breast Cancer', 'Cancer Education', 'Drug De...
# Kelly Hunt               ['Breast Cancer', 'Sarcoma', 'Clinical Trials/...
# Fergus Couch                                                            []
# Monica Morrow                                            ['Breast Cancer']
# Lajos Pusztai            ['Breast Cancer', 'Clinical Trials/Biostatisti...
# Funda Meric-Bernstam     ['Breast Cancer', 'Laboratory Research', 'Tumo...
# Eric P. Winer            ['Breast Cancer', 'Clinical Trials/Biostatisti...
# Edith A. Perez           ['Breast Cancer', 'Cancer Education', 'Cancer ...
# Vicente Valero           ['Breast Cancer', 'Clinical Trials/Biostatisti...
# Banu Arun                                                ['Breast Cancer']
# Naoto T. Ueno            ['Breast Cancer', 'Clinical Research', 'Develo...
# Claudine Isaacs          ['Breast Cancer', 'Clinical Research', 'Geneti...
# Larry Norton                        ['Breast Cancer', 'Clinical Research']
# Kenneth Offit                                            ['Tumor Biology']
# Elizabeth A. Mittendorf              ['Immunology/Immunobiology/Vaccines']
# Adam Brufsky             ['Breast Cancer', 'Cancer Education', 'Clinica...
# Antonio C. Wolff         ['Breast Cancer', 'Clinical Research', 'Clinic...
# Amy C. Degnim                                            ['Breast Cancer']
# Stephen B. Edge                                          ['Breast Cancer']
# Vered Stearns                                            ['Breast Cancer']
# Sharon H. Giordano                                       ['Breast Cancer']
# Ann H. Partridge         ['Breast Cancer', 'Psychosocial Issues/Psychia...
# Charis Eng               ['Breast Cancer', 'Endocrine Tumors', 'Genetic...
# Isabelle Bedrosian                                       ['Breast Cancer']
# Anthony Lucci            ['Breast Cancer', 'Gastrointestinal Cancer', '...
# Harold J. Burstein       ['Breast Cancer', 'Clinical Trials/Biostatisti...
# Saundra S. Buys                 ['Breast Cancer', 'Genetics/Gene Therapy']
# Debu Tripathy            ['Breast Cancer', 'Clinical Trials/Biostatisti...
# Anees B. Chagpar         ['Breast Cancer', 'Cancer Diagnosis/Staging/Pr...
# Paul E. Goss             ['Breast Cancer', 'Cancer Prevention', 'Clinic...
# ...                                                                    ...
# Milind M. Javle                     ['Stomach Cancer', 'Drug Development']
# Rachna T. Shroff         ['Gastrointestinal Cancer', 'Liver Cancer', 'P...
# Michael P. La Quaglia    ['Endocrine Tumors', 'Laboratory Research', 'P...
# Craig C. Hofmeister      ['Multiple Myeloma', 'BMT (Autologous/Allogene...
# Y. Nancy You             ['Gastrointestinal Cancer', 'Clinical Trials/B...
# David A. Liebner                    ['Melanoma', 'Sarcoma', 'Informatics']
# Vincent T. DeVita                    ['Drug Development', 'Tumor Biology']
# Mahesh Seetharam                            ['Developmental Therapeutics']
# Michael J. Mastrangelo   ['Melanoma', 'Biologic Therapy', 'Immunology/I...
# Rafael Arteta-Bulos      ['Clinical Research', 'Clinical Trials/Biostat...
# Namrata Vijayvergia      ['Colorectal Cancer', 'Gastrointestinal Cancer...
# Ferdinandos Skoulidis                                ['Cancer Prevention']
# Haider Mahdi             ['Cervical Cancer', 'Ovarian Cancer', 'Uterine...
# Nikhil I. Khushalani     ['Melanoma', 'Sarcoma', 'Clinical Research', '...
# Amod Sarnaik                                                     ['Other']
# Lisa Diamond                                                            []
# Susan Anitra Melin       ['Breast Cancer', 'Cancer Diagnosis/Staging/Pr...
# Gary C. Doolittle        ['Melanoma', 'Sarcoma', 'Cancer Diagnosis/Stag...
# Ryan D. Gentzler         ['Lung Cancer', 'Cancer Diagnosis/Staging/Prog...
# Mary Helen Hackney       ['Breast Cancer', 'Cancer Diagnosis/Staging/Pr...
# Jill N. Allen            ['Gastrointestinal Cancer', 'Liver Cancer', 'P...
# Sandip Pravin Patel      ['Lung Cancer', 'Administration', 'Biologic Th...
# Philip Agop Philip       ['Gastrointestinal Cancer', 'Liver Cancer', 'D...
# Jerome Ritz              ['BMT (Autologous/Allogeneic/Stem Cell)', 'Imm...
# Rachel N. Grisham                                                       []
# William R. Jarnagin                                                     []
# Ellis Glenn Levine                  ['Breast Cancer', 'Clinical Research']
# Valerie Klairisa Reed    ['Breast Cancer', 'Lung Cancer', 'Lymphoma', '...
# Abdulraheem Yacoub                                                      []
# Yanis Boumber            ['Lung Cancer', 'Laboratory Research', 'Tumor ...
#
#                                                                certificate  \
# name
# Gabriel N. Hortobagyi            ['Internal Medicine', 'Medical Oncology']
# Kelly Hunt                                           ['Surgical Oncology']
# Fergus Couch                                                            []
# Monica Morrow                                        ['Surgical Oncology']
# Lajos Pusztai                    ['Internal Medicine', 'Medical Oncology']
# Funda Meric-Bernstam                                 ['Surgical Oncology']
# Eric P. Winer                                         ['Medical Oncology']
# Edith A. Perez           ['Hematology', 'Internal Medicine', 'Medical O...
# Vicente Valero           ['Hematology', 'Internal Medicine', 'Medical O...
# Banu Arun                               ['Hematology', 'Medical Oncology']
# Naoto T. Ueno                    ['Internal Medicine', 'Medical Oncology']
# Claudine Isaacs                  ['Internal Medicine', 'Medical Oncology']
# Larry Norton                                          ['Medical Oncology']
# Kenneth Offit                           ['Hematology', 'Medical Oncology']
# Elizabeth A. Mittendorf                              ['Surgical Oncology']
# Adam Brufsky                     ['Internal Medicine', 'Medical Oncology']
# Antonio C. Wolff         ['Medical Oncology', 'Medical Oncology', 'Medi...
# Amy C. Degnim                                        ['Surgical Oncology']
# Stephen B. Edge                                      ['Surgical Oncology']
# Vered Stearns                                         ['Medical Oncology']
# Sharon H. Giordano               ['Internal Medicine', 'Medical Oncology']
# Ann H. Partridge                        ['Hematology', 'Medical Oncology']
# Charis Eng               ['Internal Medicine', 'Medical Oncology', 'Oth...
# Isabelle Bedrosian                                   ['Surgical Oncology']
# Anthony Lucci                                        ['Surgical Oncology']
# Harold J. Burstein               ['Internal Medicine', 'Medical Oncology']
# Saundra S. Buys                         ['Hematology', 'Medical Oncology']
# Debu Tripathy                    ['Internal Medicine', 'Medical Oncology']
# Anees B. Chagpar                                       ['General Surgery']
# Paul E. Goss                                          ['Medical Oncology']
# ...                                                                    ...
# Milind M. Javle                                       ['Medical Oncology']
# Rachna T. Shroff                 ['Internal Medicine', 'Medical Oncology']
# Michael P. La Quaglia                  ['Pediatrics', 'Surgical Oncology']
# Craig C. Hofmeister                                         ['Hematology']
# Y. Nancy You                                                            []
# David A. Liebner                       ['Hematology', 'Internal Medicine']
# Vincent T. DeVita                ['Internal Medicine', 'Medical Oncology']
# Mahesh Seetharam         ['Hematology', 'Internal Medicine', 'Medical O...
# Michael J. Mastrangelo           ['Internal Medicine', 'Medical Oncology']
# Rafael Arteta-Bulos      ['Hematology', 'Internal Medicine', 'Medical O...
# Namrata Vijayvergia      ['Hematology', 'Internal Medicine', 'Medical O...
# Ferdinandos Skoulidis                                                   []
# Haider Mahdi                                      ['Gynecologic Oncology']
# Nikhil I. Khushalani             ['Internal Medicine', 'Medical Oncology']
# Amod Sarnaik                                         ['Surgical Oncology']
# Lisa Diamond                                         ['Internal Medicine']
# Susan Anitra Melin       ['Hematology', 'Internal Medicine', 'Medical O...
# Gary C. Doolittle                       ['Hematology', 'Medical Oncology']
# Ryan D. Gentzler                 ['Internal Medicine', 'Medical Oncology']
# Mary Helen Hackney       ['Hospice and Palliative Medicine', 'Medical O...
# Jill N. Allen                                         ['Medical Oncology']
# Sandip Pravin Patel      ['Hematology', 'Internal Medicine', 'Medical O...
# Philip Agop Philip               ['Internal Medicine', 'Medical Oncology']
# Jerome Ritz                            ['Hematology', 'Internal Medicine']
# Rachel N. Grisham                ['Internal Medicine', 'Medical Oncology']
# William R. Jarnagin                                  ['Surgical Oncology']
# Ellis Glenn Levine               ['Internal Medicine', 'Medical Oncology']
# Valerie Klairisa Reed                      ['Other', 'Radiation Oncology']
# Abdulraheem Yacoub       ['Hematology', 'Internal Medicine', 'Medical O...
# Yanis Boumber                    ['Internal Medicine', 'Medical Oncology']
#
#                                                                center_name  \
# name
# Gabriel N. Hortobagyi    The University of Texas MD Anderson Cancer Center
# Kelly Hunt               The University of Texas MD Anderson Cancer Center
# Fergus Couch                                     Mayo Clinic Cancer Center
# Monica Morrow                       Memorial Sloan-Kettering Cancer Center
# Lajos Pusztai                                           Yale Cancer Center
# Funda Meric-Bernstam     The University of Texas MD Anderson Cancer Center
# Eric P. Winer                            Dana-Farber/Harvard Cancer Center
# Edith A. Perez                                   Mayo Clinic Cancer Center
# Vicente Valero           The University of Texas MD Anderson Cancer Center
# Banu Arun                The University of Texas MD Anderson Cancer Center
# Naoto T. Ueno            The University of Texas MD Anderson Cancer Center
# Claudine Isaacs            Georgetown Lombardi Comprehensive Cancer Center
# Larry Norton                        Memorial Sloan-Kettering Cancer Center
# Stephen B. Edge          [17577210, 20461766, 15577294, 16432358, 23099...
# Vered Stearns            [11923129, 20496259, 28366577, 27124919, 24636...
# Sharon H. Giordano       [29387884, 19307509, 19067255, 19524392, 22371...
# Ann H. Partridge         [25784579, 18180462, 22056355, 23099438, 25133...
# Charis Eng               [23740344, 24458845, 29349711, 25149476, 16436...
# Isabelle Bedrosian       [15708847, 29733510, 24809301, 28135395, 20647...
# Anthony Lucci            [30005774, 26017070, 21334874, 28423171, 30248...
# Harold J. Burstein       [19652071, 17509259, 27484879, 16507275, 24663...
# Saundra S. Buys          [18704680, 17021353, 21118973, 19188678, 11792...
# Debu Tripathy            [28860112, 28135395, 15899072, 12516039, 27146...
# Anees B. Chagpar         [23942872, 26255230, 24882342, 31018921, 25902...
# Paul E. Goss             [24636210, 21911723, 24872111, 30241268, 26728...
# ...                                                                    ...
# Milind M. Javle                                                 [15578717]
# Rachna T. Shroff                                                [28487467]
# Michael P. La Quaglia                                           [18338809]
# Craig C. Hofmeister                                             [23610125]
# Y. Nancy You                                                    [25185467]
# David A. Liebner                                                [25687217]
# Vincent T. DeVita                                               [27002947]
# Mahesh Seetharam                                                [29411654]
# Michael J. Mastrangelo                                          [23594177]
# Rafael Arteta-Bulos                                             [24390424]
# Namrata Vijayvergia                                             [28591715]
# Ferdinandos Skoulidis                                           [26420858]
# Haider Mahdi                                                    [26067864]
# Nikhil I. Khushalani                                            [25772798]
# Amod Sarnaik                                                    [23874673]
# Lisa Diamond                                                    [25574581]
# Susan Anitra Melin                                              [28196257]
# Gary C. Doolittle                                               [15998626]
# Ryan D. Gentzler                                                [22494490]
# Mary Helen Hackney                                              [18841034]
# Jill N. Allen                                                   [17189839]
# Sandip Pravin Patel                                             [30609392]
# Philip Agop Philip                                              [12811511]
# Jerome Ritz                                                     [23306378]
# Rachel N. Grisham                                               [22139894]
# William R. Jarnagin                                             [26445472]
# Ellis Glenn Levine                                              [29778787]
# Valerie Klairisa Reed                                           [22184734]
# Abdulraheem Yacoub                                              [20953809]
# Yanis Boumber                                                   [26285240]
#
#                          query_pmid_num  \
# name
# Gabriel N. Hortobagyi               506
# Kelly Hunt                          347
# Fergus Couch                        289
# Monica Morrow                       267
# Lajos Pusztai                       240
# Funda Meric-Bernstam                230
# Eric P. Winer                       229
# Edith A. Perez                      226
# Vicente Valero                      212
# Banu Arun                           170
# Naoto T. Ueno                       163
# Claudine Isaacs                     161
# Larry Norton                        158
# Kenneth Offit                       142
# Elizabeth A. Mittendorf             137
# Adam Brufsky                        136
# Antonio C. Wolff                    131
# Amy C. Degnim                       128
# Stephen B. Edge                     128
# Vered Stearns                       127
# Sharon H. Giordano                  116
# Ann H. Partridge                    116
# Charis Eng                          109
# Isabelle Bedrosian                  108
# Anthony Lucci                       102
# Harold J. Burstein                   97
# Saundra S. Buys                      96
# Debu Tripathy                        95
# Anees B. Chagpar                     91
# Paul E. Goss                         89
# ...                                 ...
# Milind M. Javle                       1
# Rachna T. Shroff                      1
# Michael P. La Quaglia                 1
# Debu Tripathy            [171, 281, 541, 641, 658, 703, 750, 800, 905, ...
# Anees B. Chagpar         [101, 155, 163, 237, 243, 265, 288, 292, 423, ...
# Paul E. Goss             [728, 906, 953, 1059, 1423, 1568, 1618, 1657, ...
# ...                                                                    ...
# Milind M. Javle                                                     [4966]
# Rachna T. Shroff                                                    [5030]
# Michael P. La Quaglia                                               [5187]
# Craig C. Hofmeister                                                 [5210]
# Y. Nancy You                                                        [4119]
# David A. Liebner                                                    [4103]
# Vincent T. DeVita                                                   [4052]
# Mahesh Seetharam                                                    [4039]
# Michael J. Mastrangelo                                              [3009]
# Rafael Arteta-Bulos                                                 [3176]
# Namrata Vijayvergia                                                 [3184]
# Ferdinandos Skoulidis                                               [3198]
# Haider Mahdi                                                        [3200]
# Nikhil I. Khushalani                                                [3351]
# Amod Sarnaik                                                        [3423]
# Lisa Diamond                                                        [3431]
# Susan Anitra Melin                                                  [3444]
# Gary C. Doolittle                                                   [3458]
# Ryan D. Gentzler                                                    [3471]
# Mary Helen Hackney                                                  [3472]
# Jill N. Allen                                                       [3635]
# Sandip Pravin Patel                                                 [3654]
# Philip Agop Philip                                                  [3673]
# Jerome Ritz                                                         [3778]
# Rachel N. Grisham                                                   [3812]
# William R. Jarnagin                                                 [3917]
# Ellis Glenn Levine                                                  [3923]
# Valerie Klairisa Reed                                               [3984]
# Abdulraheem Yacoub                                                  [4011]
# Yanis Boumber                                                       [8548]
#
#                          pmid_rank_10th_percentile
# name
# Gabriel N. Hortobagyi                            2
# Kelly Hunt                                       3
# Fergus Couch                                     1
# Monica Morrow                                    3
# Lajos Pusztai                                    1
# Funda Meric-Bernstam                             2
# Eric P. Winer                                    2
# Edith A. Perez                                   1
# Vicente Valero                                   2
# Banu Arun                                        5
# Naoto T. Ueno                                    4
# Claudine Isaacs                                  2
# Larry Norton                                     0
# Kenneth Offit                                    1
# Elizabeth A. Mittendorf                          1
# Adam Brufsky                                     2
# Antonio C. Wolff                                 0
# Amy C. Degnim                                    2
# Stephen B. Edge                                  0
# Vered Stearns                                    0
# Sharon H. Giordano                               0
# Ann H. Partridge                                 0
# Charis Eng                                       1
# Isabelle Bedrosian                               2
# Anthony Lucci                                    2
# Harold J. Burstein                               1
# Saundra S. Buys                                  2
# Debu Tripathy                                    0
# Anees B. Chagpar                                 0
# Paul E. Goss                                     0
# ...                                            ...
# Milind M. Javle                                  0
# Rachna T. Shroff                                 0
# Michael P. La Quaglia                            0
# Craig C. Hofmeister                              0
# Y. Nancy You                                     0
# David A. Liebner                                 0
# Vincent T. DeVita                                0
# Mahesh Seetharam                                 0
# Michael J. Mastrangelo                           0
# Rafael Arteta-Bulos                              0
# Namrata Vijayvergia                              0
# Ferdinandos Skoulidis                            0
# Haider Mahdi                                     0
# Nikhil I. Khushalani                             0
# Amod Sarnaik                                     0
# Lisa Diamond                                     0
# Susan Anitra Melin                               0
# Gary C. Doolittle                                0
# Ryan D. Gentzler                                 0
# Mary Helen Hackney                               0
# Jill N. Allen                                    0
# Sandip Pravin Patel                              0
# Philip Agop Philip                               0
# Jerome Ritz                                      0
# Rachel N. Grisham                                0
# William R. Jarnagin                              0
# Ellis Glenn Levine                               0
# Valerie Klairisa Reed                            0
# Abdulraheem Yacoub                               0
# Yanis Boumber                                    0
#
# [799 rows x 15 columns]

# %%
onco=Oncomatch_model(cancer_type)
similarity_df=onco.get_similarity_scores(original_text)   ## (8563, 2)

# %%
doctor2cancer_dict=pickle.load(open(os.path.join(base_dir, "data/doctor2cancer_dict.pkl"),"rb"))
cancer2doctor_dict=pickle.load(open(os.path.join(base_dir, "data/cancer2doctor_dict.pkl"),"rb"))
mskcc_text_df=pd.read_csv(os.path.join(base_dir, 'data/mskcc_text_dict_df.csv'),index_col='name')
mskcc_text_df.index
# Out:
# Index(['Kenneth H. Yu', 'Robert Sidlow', 'Lisa Marie Ruppert', 'Yukio Sonoda',
#        'Marsha Reyngold', 'Andrea Veronica Barrio', 'Seth M. Cohen',
#        'Sam S. Yoon', 'Atif J. Khan', 'Alexandra S. Heerdt',
#        ...
#        'm-lia-palomba', 'mario-leitao-jr', 'julia-glade-bender',
#        'diane-reidy-lagunes', 'j-smith', 'sre-bhavani-chalasani',
#        'david-paul-kelsen', 'linda-vahdat', 'mary-sue-brady', 'iris-zhi'],
#       dtype='object', name='name', length=170)

# %% [markdown]
# ### Jedd D. Wolchok

# %%
onco_name = 'Jedd D. Wolchok'
doctor2cancer_dict[onco_name]
# Out:
# ['Breast Cancer',
#  'Lung Cancer',
#  'Leukemia',
#  'Prostate Cancer',
#  'Colorectal Cancer',
#  'Lymphoma',
#  'Bone Cancer',
#  'Melanoma',
#  'Liver Cancer',
#  'Kidney Cancer',
#  'Ovarian Cancer',
#  'Pancreatic Cancer',
#  'Brain Tumor',
#  'Head and Neck Cancer',
#  'Acute Myeloid Leukemia (AML)',
#  'Sarcoma',
#  'Bladder Cancer',
#  'Skin Cancer',
#  'Gastric Cancer',
#  'Gastrointestinal Tumor',
#  'Endometrial Cancer',
#  'Cardiac Tumors',
#  'Thyroid Cancer',
#  'Neuroblastoma',
#  'Testicular Cancer',
#  'Osteosarcoma',
#  'Anal Cancer',
#  'Gallbladder Cancer',
#  'Wilms Tumor',
#  'Pituitary Tumor']

# %%
## Get rank of similarity scores
#original_text = 'The patient is looking for therapies for breast cancer'
#original_text = 'This tumor is very malignant and aggressive. It tends to metastasize to multiple organs. The patient may not respond to targeted therapy but may become sensitive to immunotherapy after themotherapy.'
cancer_type='Melanoma'
original_text=mskcc_text_df.loc[onco_name,'text']
onco=Oncomatch_model(cancer_type)
similarity_df=onco.get_similarity_scores(original_text)   ## (8563, 2)

# %%
original_text
# Out:
# 'I am a medical oncologist who specializes in caring for people with melanoma. As a researcher, I am working to develop innovative ways to use the immune system to treat cancer. I have been at the forefront of cancer immunotherapy as a clinician-scientist and as a principal investigator of several pivotal clinical trials.Read moreOne of these was a large phase III trial that led to the FDA approval of ipilimumab (Yervoy®), an antibody now used as a first-line treatment for people with advanced melanoma. Ipilimumab was the first drug ever shown to improve survival in these patients. It has fundamentally changed this disease’s outcome — people who were once given a matter of months are living years longer in some cases. A number of patients I treated with ipilimumab in 2004 are still alive and free of cancer today. As a physician, nothing is more gratifying than being able to give someone his or her life back after cancer.Despite the successes of ipilimumab, only about 20 percent of melanoma patients respond to the drug. This experience led me to test ipilimumab in combination with another immune drug, called nivolumab. I designed and led the phase I, II, and III clinical trials that led to the FDA approval of this combination in 2015 for advanced melanoma. You can hear about one patient’s experience with this combination here.In 2011, I established the Immunotherapeutics Clinical Core, a specialized phase I outpatient unit at MSK that conducts novel immunotherapy trials, with a specific emphasis on identifying molecular biomarkers that can predict response. This group treats patients with a variety of cancers and has become a model for similar efforts by other major cancer centers throughout the world.I received my undergraduate degree from Princeton University and my MD and PhD degrees from New York University, where I also fulfilled my residency program. After completing my fellowship at MSK, I remained on the faculty as part of the Melanoma and Immunotherapeutics Service. I am also a professor of medicine at Weill Cornell Medical College.'

# %%
## Gene filtering
gene_name = 'NA'
if gene_name != 'NA':
    pmid_gene=Get_info().gene_to_pmid(gene_name, gene_df)
    pmid_list=[]
    for i in similarity_df.pmid:
        if i in pmid_gene:
            pmid_list.append(i)
else:
    pmid_list=list(similarity_df.pmid)   ## 865

# %%
## clinical trial filtering and get oncologist info
clinical_trial = True
test_df = onco.get_onco_info(pmid_list,clinical_trial)   ## (95, 16)

# %%
test_df.head()
# Out:
#                                   name           degree  \
# name
# Jedd D. Wolchok        Jedd D. Wolchok   MD, PhD, FASCO
# Patrick Hwu                Patrick Hwu               MD
# Keith Flaherty          Keith Flaherty               MD
# Craig L. Slingluff  Craig L. Slingluff               MD
# Kevin Kim                    Kevin Kim               MD
#
#                                       phone  \
# name
# Jedd D. Wolchok              (646) 888-2395
# Patrick Hwu         Search for Phone Number
# Keith Flaherty               (617) 726-1941
# Craig L. Slingluff           (434) 924-1730
# Kevin Kim                    (203) 785-4747
#
#                                                      center_name2  \
# name
# Jedd D. Wolchok            Memorial Sloan Kettering Cancer Center
# Patrick Hwu         University of Texas MD Anderson Cancer Center
# Keith Flaherty                     Massachusetts General Hospital
# Craig L. Slingluff                         University of Virginia
# Kevin Kim                                      Yale Cancer Center
#
#                                           address  \
# name
# Jedd D. Wolchok              1275 York AveBox 340
# Patrick Hwu            1515 Holcombe BlvdUnit 430
# Keith Flaherty               55 Fruit StYawkey 9E
# Craig L. Slingluff                  PO Box 800709
# Kevin Kim           PO Box 208042333 Cedar Street
#
#                                             city_state  \
# name
# Jedd D. Wolchok                 New York, NY 10021, US
# Patrick Hwu                      Houston, TX 77030, US
# Keith Flaherty                    Boston, MA 02114, US
# Craig L. Slingluff  Charlottesville, VA 22908-0709, US
# Kevin Kim                 New Haven, CT 06520-8042, US
#
#                                                            speciality  \
# name
# Jedd D. Wolchok     ['Melanoma', 'Clinical Trials/Biostatistics/Ep...
# Patrick Hwu         ['Melanoma', 'Immunology/Immunobiology/Vaccines']
# Keith Flaherty      ['Melanoma', 'Clinical Trials/Biostatistics/Ep...
# Craig L. Slingluff  ['Melanoma', 'Biologic Therapy', 'Clinical Res...
# Kevin Kim           ['Gastrointestinal Cancer', 'Liver Cancer', 'L...
#
#                                                           certificate  \
# name
# Jedd D. Wolchok                    ['Hematology', 'Medical Oncology']
# Patrick Hwu                                      ['Medical Oncology']
# Keith Flaherty                     ['Hematology', 'Medical Oncology']
# Craig L. Slingluff                                ['General Surgery']
# Kevin Kim           ['Interventional Radiology/Diagnostic Radiology']
#
#                                                           center_name  \
# name
# Jedd D. Wolchok                Memorial Sloan-Kettering Cancer Center
# Patrick Hwu         The University of Texas MD Anderson Cancer Center
# Keith Flaherty                         Massachusetts General Hospital
# Craig L. Slingluff               University of Virginia Cancer Center
# Kevin Kim                                          Yale Cancer Center
#
#                     article_num  clinical_trial_num  \
# name
# Jedd D. Wolchok             279                   7
# Patrick Hwu                 182                   5
# Keith Flaherty              299                   7
# Craig L. Slingluff          111                  25
# Kevin Kim                   115                  18
#
#                                                            query_pmid  \
# name
# Jedd D. Wolchok     [19558193, 26317466, 15800947, 28841387, 19103...
# Patrick Hwu         [21166498, 24292706, 28754817, 21111964, 27678...
# Keith Flaherty      [31358999, 19659612, 26037941, 28728868, 25265...
# Craig L. Slingluff  [22435430, 23406162, 14734458, 24047116, 20221...
# Kevin Kim           [24720932, 23800008, 25962795, 22668797, 25148...
#
#                     query_pmid_num  \
# name
# Jedd D. Wolchok                202
# Patrick Hwu                    142
# Keith Flaherty                 213
# Craig L. Slingluff              93
# Kevin Kim                       92
#
#                                                             pmid_rank  \
# name
# Jedd D. Wolchok     [7, 8, 17, 26, 45, 53, 77, 78, 82, 84, 115, 12...
# Patrick Hwu         [24, 35, 40, 47, 65, 67, 71, 105, 119, 139, 16...
# Keith Flaherty      [15, 20, 48, 60, 72, 87, 101, 113, 126, 128, 1...
# Craig L. Slingluff  [21, 25, 44, 135, 374, 401, 432, 545, 554, 560...
# Kevin Kim           [3, 6, 49, 67, 71, 109, 133, 136, 139, 143, 14...
#
#                     pmid_rank_10th_percentile  clinical_trial_num2
# name
# Jedd D. Wolchok                             5                    6
# Patrick Hwu                                 4                    5
# Keith Flaherty                              3                    5
# Craig L. Slingluff                          3                   21
# Kevin Kim                                   3                   13

# %%
test_df.loc[onco_name]
# Out:
# name                                                           Jedd D. Wolchok
# degree                                                          MD, PhD, FASCO
# phone                                                           (646) 888-2395
# center_name2                            Memorial Sloan Kettering Cancer Center
# address                                                   1275 York AveBox 340
# city_state                                              New York, NY 10021, US
# speciality                   ['Melanoma', 'Clinical Trials/Biostatistics/Ep...
# certificate                                 ['Hematology', 'Medical Oncology']
# center_name                             Memorial Sloan-Kettering Cancer Center
# article_num                                                                279
# clinical_trial_num                                                           7
# query_pmid                   [19558193, 26317466, 15800947, 28841387, 19103...
# query_pmid_num                                                             202
# pmid_rank                    [7, 8, 17, 26, 45, 53, 77, 78, 82, 84, 115, 12...
# pmid_rank_10th_percentile                                                    5
# clinical_trial_num2                                                          6
# Name: Jedd D. Wolchok, dtype: object

# %% [markdown]
# ### Charles L. Sawyers

# %%
onco_name = 'Charles L. Sawyers'
doctor2cancer_dict[onco_name]
# Out:
# ['Breast Cancer',
#  'Lung Cancer',
#  'Leukemia',
#  'Prostate Cancer',
#  'Colorectal Cancer',
#  'Lymphoma',
#  'Bone Cancer',
#  'Melanoma',
#  'Liver Cancer',
#  'Kidney Cancer',
#  'Pancreatic Cancer',
#  'Brain Tumor',
#  'Head and Neck Cancer',
#  'Acute Myeloid Leukemia (AML)',
#  'Sarcoma',
#  'Bladder Cancer',
#  'Skin Cancer',
#  'Gastrointestinal Tumor',
#  'Endometrial Cancer',
#  'Acute Lymphoblastic Leukemia (ALL)',
#  'Cardiac Tumors',
#  'Thyroid Cancer',
#  'Myeloproliferative Neoplasms',
#  'Chronic Myelogenous Leukemia (CML)',
#  'Ewing Sarcoma']

# %%
## Get rank of similarity scores
#original_text = 'The patient is looking for therapies for breast cancer'
#original_text = 'This tumor is very malignant and aggressive. It tends to metastasize to multiple organs. The patient may not respond to targeted therapy but may become sensitive to immunotherapy after themotherapy.'
cancer_type='Prostate Cancer'
original_text=mskcc_text_df.loc[onco_name,'text']
onco=Oncomatch_model(cancer_type)
similarity_df=onco.get_similarity_scores(original_text)   ## (8563, 2)

# %%
## Gene filtering
gene_name = 'NA'
if gene_name != 'NA':
    pmid_gene=Get_info().gene_to_pmid(gene_name, gene_df)
    pmid_list=[]
    for i in similarity_df.pmid:
        if i in pmid_gene:
            pmid_list.append(i)
else:
    pmid_list=list(similarity_df.pmid)   ## 865

# %%
## clinical trial filtering and get oncologist info
clinical_trial = False
test_df = onco.get_onco_info(pmid_list,clinical_trial)   ## (95, 16)

# %%
test_df.sort_values(by=['query_pmid_num'],ascending=False)
# Out:
#                                             name  \
# name
# Gabriel N. Hortobagyi      Gabriel N. Hortobagyi
# Kelly Hunt                            Kelly Hunt
# Fergus Couch                        Fergus Couch
# Monica Morrow                      Monica Morrow
# Lajos Pusztai                      Lajos Pusztai
# Funda Meric-Bernstam        Funda Meric-Bernstam
# Eric P. Winer                      Eric P. Winer
# Edith A. Perez                    Edith A. Perez
# Vicente Valero                    Vicente Valero
# Banu Arun                              Banu Arun
# Naoto T. Ueno                      Naoto T. Ueno
# Claudine Isaacs                  Claudine Isaacs
# Larry Norton                        Larry Norton
# Kenneth Offit                      Kenneth Offit
# Elizabeth A. Mittendorf  Elizabeth A. Mittendorf
# Adam Brufsky                        Adam Brufsky
# Antonio C. Wolff                Antonio C. Wolff
# Amy C. Degnim                      Amy C. Degnim
# Stephen B. Edge                  Stephen B. Edge
# Vered Stearns                      Vered Stearns
# Sharon H. Giordano            Sharon H. Giordano
# Ann H. Partridge                Ann H. Partridge
# Charis Eng                            Charis Eng
# Isabelle Bedrosian            Isabelle Bedrosian
# Anthony Lucci                      Anthony Lucci
# Harold J. Burstein            Harold J. Burstein
# Saundra S. Buys                  Saundra S. Buys
# Debu Tripathy                      Debu Tripathy
# Anees B. Chagpar                Anees B. Chagpar
# Paul E. Goss                        Paul E. Goss
# ...                                          ...
# Milind M. Javle                  Milind M. Javle
# Rachna T. Shroff                Rachna T. Shroff
# Michael P. La Quaglia      Michael P. La Quaglia
# Nikhil I. Khushalani               Tampa, FL 33612-9416, US
# Amod Sarnaik                       Tampa, FL 33612-9416, US
# Lisa Diamond             MANHASSET, New York 11030-2419, US
# Susan Anitra Melin         Winston Salem, NC 27157-1082, US
# Gary C. Doolittle            Kansas City, KS 66160-0001, US
# Ryan D. Gentzler         Charlottesville, VA 22908-0716, US
# Mary Helen Hackney                   Richmond, VA 23298, US
# Jill N. Allen                          Boston, MA 02114, US
# Sandip Pravin Patel             La Jolla, CA 92093-1503, US
# Philip Agop Philip               Detroit, MI 48201-2013, US
# Jerome Ritz                       Boston, MA 02215-5418, US
# Rachel N. Grisham                   New York , NY 10065, US
# William R. Jarnagin                  New York, NY 10021, US
# Ellis Glenn Levine               Buffalo, NY 14263-0001, US
# Valerie Klairisa Reed                 Houston, TX 77030, US
# Abdulraheem Yacoub              Westwood, KS 66205-2005, US
# Yanis Boumber                    Philadelphia, PA 19111, US
#
#                                                                 speciality  \
# name
# Gabriel N. Hortobagyi    ['Breast Cancer', 'Cancer Education', 'Drug De...
# Kelly Hunt               ['Breast Cancer', 'Sarcoma', 'Clinical Trials/...
# Fergus Couch                                                            []
# Monica Morrow                                            ['Breast Cancer']
# Lajos Pusztai            ['Breast Cancer', 'Clinical Trials/Biostatisti...
# Funda Meric-Bernstam     ['Breast Cancer', 'Laboratory Research', 'Tumo...
# Eric P. Winer            ['Breast Cancer', 'Clinical Trials/Biostatisti...
# Edith A. Perez           ['Breast Cancer', 'Cancer Education', 'Cancer ...
# Vicente Valero           ['Breast Cancer', 'Clinical Trials/Biostatisti...
# Banu Arun                                                ['Breast Cancer']
# Naoto T. Ueno            ['Breast Cancer', 'Clinical Research', 'Develo...
# Claudine Isaacs          ['Breast Cancer', 'Clinical Research', 'Geneti...
# Larry Norton                        ['Breast Cancer', 'Clinical Research']
# Kenneth Offit                                            ['Tumor Biology']
# Elizabeth A. Mittendorf              ['Immunology/Immunobiology/Vaccines']
# Adam Brufsky             ['Breast Cancer', 'Cancer Education', 'Clinica...
# Antonio C. Wolff         ['Breast Cancer', 'Clinical Research', 'Clinic...
# Amy C. Degnim                                            ['Breast Cancer']
# Stephen B. Edge                                          ['Breast Cancer']
# Vered Stearns                                            ['Breast Cancer']
# Sharon H. Giordano                                       ['Breast Cancer']
# Ann H. Partridge         ['Breast Cancer', 'Psychosocial Issues/Psychia...
# Charis Eng               ['Breast Cancer', 'Endocrine Tumors', 'Genetic...
# Isabelle Bedrosian                                       ['Breast Cancer']
# Anthony Lucci            ['Breast Cancer', 'Gastrointestinal Cancer', '...
# Harold J. Burstein       ['Breast Cancer', 'Clinical Trials/Biostatisti...
# Saundra S. Buys                 ['Breast Cancer', 'Genetics/Gene Therapy']
# Debu Tripathy            ['Breast Cancer', 'Clinical Trials/Biostatisti...
# Anees B. Chagpar         ['Breast Cancer', 'Cancer Diagnosis/Staging/Pr...
# Paul E. Goss             ['Breast Cancer', 'Cancer Prevention', 'Clinic...
# ...                                                                    ...
# Milind M. Javle                     ['Stomach Cancer', 'Drug Development']
# Rachna T. Shroff         ['Gastrointestinal Cancer', 'Liver Cancer', 'P...
# Michael P. La Quaglia    ['Endocrine Tumors', 'Laboratory Research', 'P...
# Craig C. Hofmeister      ['Multiple Myeloma', 'BMT (Autologous/Allogene...
# Y. Nancy You             ['Gastrointestinal Cancer', 'Clinical Trials/B...
# David A. Liebner                    ['Melanoma', 'Sarcoma', 'Informatics']
# Vincent T. DeVita                    ['Drug Development', 'Tumor Biology']
# Mahesh Seetharam                            ['Developmental Therapeutics']
# Michael J. Mastrangelo   ['Melanoma', 'Biologic Therapy', 'Immunology/I...
# Rafael Arteta-Bulos      ['Clinical Research', 'Clinical Trials/Biostat...
# Namrata Vijayvergia      ['Colorectal Cancer', 'Gastrointestinal Cancer...
# Ferdinandos Skoulidis                                ['Cancer Prevention']
# Haider Mahdi             ['Cervical Cancer', 'Ovarian Cancer', 'Uterine...
# Nikhil I. Khushalani     ['Melanoma', 'Sarcoma', 'Clinical Research', '...
# Amod Sarnaik                                                     ['Other']
# Lisa Diamond                                                            []
# Susan Anitra Melin       ['Breast Cancer', 'Cancer Diagnosis/Staging/Pr...
# Gary C. Doolittle        ['Melanoma', 'Sarcoma', 'Cancer Diagnosis/Stag...
# Ryan D. Gentzler         ['Lung Cancer', 'Cancer Diagnosis/Staging/Prog...
# Mary Helen Hackney       ['Breast Cancer', 'Cancer Diagnosis/Staging/Pr...
# Jill N. Allen            ['Gastrointestinal Cancer', 'Liver Cancer', 'P...
# Sandip Pravin Patel      ['Lung Cancer', 'Administration', 'Biologic Th...
# Philip Agop Philip       ['Gastrointestinal Cancer', 'Liver Cancer', 'D...
# Jerome Ritz              ['BMT (Autologous/Allogeneic/Stem Cell)', 'Imm...
# Rachel N. Grisham                                                       []
# William R. Jarnagin                                                     []
# Ellis Glenn Levine                  ['Breast Cancer', 'Clinical Research']
# Valerie Klairisa Reed    ['Breast Cancer', 'Lung Cancer', 'Lymphoma', '...
# Abdulraheem Yacoub                                                      []
# Yanis Boumber            ['Lung Cancer', 'Laboratory Research', 'Tumor ...
#
#                                                                certificate  \
# name
# Gabriel N. Hortobagyi            ['Internal Medicine', 'Medical Oncology']
# Kelly Hunt                                           ['Surgical Oncology']
# Fergus Couch                                                            []
# Monica Morrow                                        ['Surgical Oncology']
# Lajos Pusztai                    ['Internal Medicine', 'Medical Oncology']
# Funda Meric-Bernstam                                 ['Surgical Oncology']
# Eric P. Winer                                         ['Medical Oncology']
# Edith A. Perez           ['Hematology', 'Internal Medicine', 'Medical O...
# Vicente Valero           ['Hematology', 'Internal Medicine', 'Medical O...
# Banu Arun                               ['Hematology', 'Medical Oncology']
# Naoto T. Ueno                    ['Internal Medicine', 'Medical Oncology']
# Claudine Isaacs                  ['Internal Medicine', 'Medical Oncology']
# Larry Norton                                          ['Medical Oncology']
# Kenneth Offit                           ['Hematology', 'Medical Oncology']
# Elizabeth A. Mittendorf                              ['Surgical Oncology']
# Adam Brufsky                     ['Internal Medicine', 'Medical Oncology']
# Antonio C. Wolff         ['Medical Oncology', 'Medical Oncology', 'Medi...
# Amy C. Degnim                                        ['Surgical Oncology']
# Stephen B. Edge                                      ['Surgical Oncology']
# Vered Stearns                                         ['Medical Oncology']
# Sharon H. Giordano               ['Internal Medicine', 'Medical Oncology']
# Ann H. Partridge                        ['Hematology', 'Medical Oncology']
# Charis Eng               ['Internal Medicine', 'Medical Oncology', 'Oth...
# Isabelle Bedrosian                                   ['Surgical Oncology']
# Anthony Lucci                                        ['Surgical Oncology']
# Harold J. Burstein               ['Internal Medicine', 'Medical Oncology']
# Saundra S. Buys                         ['Hematology', 'Medical Oncology']
# Debu Tripathy                    ['Internal Medicine', 'Medical Oncology']
# Anees B. Chagpar                                       ['General Surgery']
# Paul E. Goss                                          ['Medical Oncology']
# ...                                                                    ...
# Milind M. Javle                                       ['Medical Oncology']
# Rachna T. Shroff                 ['Internal Medicine', 'Medical Oncology']
# Michael P. La Quaglia                  ['Pediatrics', 'Surgical Oncology']
# Craig C. Hofmeister                                         ['Hematology']
# Y. Nancy You                                                            []
# David A. Liebner                       ['Hematology', 'Internal Medicine']
# Vincent T. DeVita                ['Internal Medicine', 'Medical Oncology']
# Mahesh Seetharam         ['Hematology', 'Internal Medicine', 'Medical O...
# Michael J. Mastrangelo           ['Internal Medicine', 'Medical Oncology']
# Rafael Arteta-Bulos      ['Hematology', 'Internal Medicine', 'Medical O...
# Namrata Vijayvergia      ['Hematology', 'Internal Medicine', 'Medical O...
# Ferdinandos Skoulidis                                                   []
# Haider Mahdi                                      ['Gynecologic Oncology']
# Nikhil I. Khushalani             ['Internal Medicine', 'Medical Oncology']
# Amod Sarnaik                                         ['Surgical Oncology']
# Lisa Diamond                                         ['Internal Medicine']
# Susan Anitra Melin       ['Hematology', 'Internal Medicine', 'Medical O...
# Gary C. Doolittle                       ['Hematology', 'Medical Oncology']
# Ryan D. Gentzler                 ['Internal Medicine', 'Medical Oncology']
# Mary Helen Hackney       ['Hospice and Palliative Medicine', 'Medical O...
# Jill N. Allen                                         ['Medical Oncology']
# Sandip Pravin Patel      ['Hematology', 'Internal Medicine', 'Medical O...
# Philip Agop Philip               ['Internal Medicine', 'Medical Oncology']
# Jerome Ritz                            ['Hematology', 'Internal Medicine']
# Rachel N. Grisham                ['Internal Medicine', 'Medical Oncology']
# William R. Jarnagin                                  ['Surgical Oncology']
# Ellis Glenn Levine               ['Internal Medicine', 'Medical Oncology']
# Valerie Klairisa Reed                      ['Other', 'Radiation Oncology']
# Abdulraheem Yacoub       ['Hematology', 'Internal Medicine', 'Medical O...
# Yanis Boumber                    ['Internal Medicine', 'Medical Oncology']
#
#                                                                center_name  \
# name
# Gabriel N. Hortobagyi    The University of Texas MD Anderson Cancer Center
# Kelly Hunt               The University of Texas MD Anderson Cancer Center
# Fergus Couch                                     Mayo Clinic Cancer Center
# Monica Morrow                       Memorial Sloan-Kettering Cancer Center
# Lajos Pusztai                                           Yale Cancer Center
# Funda Meric-Bernstam     The University of Texas MD Anderson Cancer Center
# Eric P. Winer                            Dana-Farber/Harvard Cancer Center
# Edith A. Perez                                   Mayo Clinic Cancer Center
# Vicente Valero           The University of Texas MD Anderson Cancer Center
# Banu Arun                The University of Texas MD Anderson Cancer Center
# Naoto T. Ueno            The University of Texas MD Anderson Cancer Center
# Claudine Isaacs            Georgetown Lombardi Comprehensive Cancer Center
# Larry Norton                        Memorial Sloan-Kettering Cancer Center
# Stephen B. Edge          [17577210, 20461766, 15577294, 16432358, 23099...
# Vered Stearns            [11923129, 20496259, 28366577, 27124919, 24636...
# Sharon H. Giordano       [29387884, 19307509, 19067255, 19524392, 22371...
# Ann H. Partridge         [25784579, 18180462, 22056355, 23099438, 25133...
# Charis Eng               [23740344, 24458845, 29349711, 25149476, 16436...
# Isabelle Bedrosian       [15708847, 29733510, 24809301, 28135395, 20647...
# Anthony Lucci            [30005774, 26017070, 21334874, 28423171, 30248...
# Harold J. Burstein       [19652071, 17509259, 27484879, 16507275, 24663...
# Saundra S. Buys          [18704680, 17021353, 21118973, 19188678, 11792...
# Debu Tripathy            [28860112, 28135395, 15899072, 12516039, 27146...
# Anees B. Chagpar         [23942872, 26255230, 24882342, 31018921, 25902...
# Paul E. Goss             [24636210, 21911723, 24872111, 30241268, 26728...
# ...                                                                    ...
# Milind M. Javle                                                 [15578717]
# Rachna T. Shroff                                                [28487467]
# Michael P. La Quaglia                                           [18338809]
# Craig C. Hofmeister                                             [23610125]
# Y. Nancy You                                                    [25185467]
# David A. Liebner                                                [25687217]
# Vincent T. DeVita                                               [27002947]
# Mahesh Seetharam                                                [29411654]
# Michael J. Mastrangelo                                          [23594177]
# Rafael Arteta-Bulos                                             [24390424]
# Namrata Vijayvergia                                             [28591715]
# Ferdinandos Skoulidis                                           [26420858]
# Haider Mahdi                                                    [26067864]
# Nikhil I. Khushalani                                            [25772798]
# Amod Sarnaik                                                    [23874673]
# Lisa Diamond                                                    [25574581]
# Susan Anitra Melin                                              [28196257]
# Gary C. Doolittle                                               [15998626]
# Ryan D. Gentzler                                                [22494490]
# Mary Helen Hackney                                              [18841034]
# Jill N. Allen                                                   [17189839]
# Sandip Pravin Patel                                             [30609392]
# Philip Agop Philip                                              [12811511]
# Jerome Ritz                                                     [23306378]
# Rachel N. Grisham                                               [22139894]
# William R. Jarnagin                                             [26445472]
# Ellis Glenn Levine                                              [29778787]
# Valerie Klairisa Reed                                           [22184734]
# Abdulraheem Yacoub                                              [20953809]
# Yanis Boumber                                                   [26285240]
#
#                          query_pmid_num  \
# name
# Gabriel N. Hortobagyi               506
# Kelly Hunt                          347
# Fergus Couch                        289
# Monica Morrow                       267
# Lajos Pusztai                       240
# Funda Meric-Bernstam                230
# Eric P. Winer                       229
# Edith A. Perez                      226
# Vicente Valero                      212
# Banu Arun                           170
# Naoto T. Ueno                       163
# Claudine Isaacs                     161
# Larry Norton                        158
# Kenneth Offit                       142
# Elizabeth A. Mittendorf             137
# Adam Brufsky                        136
# Antonio C. Wolff                    131
# Amy C. Degnim                       128
# Stephen B. Edge                     128
# Vered Stearns                       127
# Sharon H. Giordano                  116
# Ann H. Partridge                    116
# Charis Eng                          109
# Isabelle Bedrosian                  108
# Anthony Lucci                       102
# Harold J. Burstein                   97
# Saundra S. Buys                      96
# Debu Tripathy                        95
# Anees B. Chagpar                     91
# Paul E. Goss                         89
# ...                                 ...
# Milind M. Javle                       1
# Rachna T. Shroff                      1
# Michael P. La Quaglia                 1
# Craig C. Hofmeister                   1
# Debu Tripathy            [171, 281, 541, 641, 658, 703, 750, 800, 905, ...
# Anees B. Chagpar         [101, 155, 163, 237, 243, 265, 288, 292, 423, ...
# Paul E. Goss             [728, 906, 953, 1059, 1423, 1568, 1618, 1657, ...
# ...                                                                    ...
# Milind M. Javle                                                     [4966]
# Rachna T. Shroff                                                    [5030]
# Michael P. La Quaglia                                               [5187]
# Craig C. Hofmeister                                                 [5210]
# Y. Nancy You                                                        [4119]
# David A. Liebner                                                    [4103]
# Vincent T. DeVita                                                   [4052]
# Mahesh Seetharam                                                    [4039]
# Michael J. Mastrangelo                                              [3009]
# Rafael Arteta-Bulos                                                 [3176]
# Namrata Vijayvergia                                                 [3184]
# Ferdinandos Skoulidis                                               [3198]
# Haider Mahdi                                                        [3200]
# Nikhil I. Khushalani                                                [3351]
# Amod Sarnaik                                                        [3423]
# Lisa Diamond                                                        [3431]
# Susan Anitra Melin                                                  [3444]
# Gary C. Doolittle                                                   [3458]
# Ryan D. Gentzler                                                    [3471]
# Mary Helen Hackney                                                  [3472]
# Jill N. Allen                                                       [3635]
# Sandip Pravin Patel                                                 [3654]
# Philip Agop Philip                                                  [3673]
# Jerome Ritz                                                         [3778]
# Rachel N. Grisham                                                   [3812]
# William R. Jarnagin                                                 [3917]
# Ellis Glenn Levine                                                  [3923]
# Valerie Klairisa Reed                                               [3984]
# Abdulraheem Yacoub                                                  [4011]
# Yanis Boumber                                                       [8548]
#
#                          pmid_rank_10th_percentile
# name
# Gabriel N. Hortobagyi                            2
# Kelly Hunt                                       3
# Fergus Couch                                     1
# Monica Morrow                                    3
# Lajos Pusztai                                    1
# Funda Meric-Bernstam                             2
# Eric P. Winer                                    2
# Edith A. Perez                                   1
# Vicente Valero                                   2
# Banu Arun                                        5
# Naoto T. Ueno                                    4
# Claudine Isaacs                                  2
# Larry Norton                                     0
# Kenneth Offit                                    1
# Elizabeth A. Mittendorf                          1
# Adam Brufsky                                     2
# Antonio C. Wolff                                 0
# Amy C. Degnim                                    2
# Stephen B. Edge                                  0
# Vered Stearns                                    0
# Sharon H. Giordano                               0
# Ann H. Partridge                                 0
# Charis Eng                                       1
# Isabelle Bedrosian                               2
# Anthony Lucci                                    2
# Harold J. Burstein                               1
# Saundra S. Buys                                  2
# Debu Tripathy                                    0
# Anees B. Chagpar                                 0
# Paul E. Goss                                     0
# ...                                            ...
# Milind M. Javle                                  0
# Rachna T. Shroff                                 0
# Michael P. La Quaglia                            0
# Craig C. Hofmeister                              0
# Y. Nancy You                                     0
# David A. Liebner                                 0
# Vincent T. DeVita                                0
# Mahesh Seetharam                                 0
# Michael J. Mastrangelo                           0
# Rafael Arteta-Bulos                              0
# Namrata Vijayvergia                              0
# Ferdinandos Skoulidis                            0
# Haider Mahdi                                     0
# Nikhil I. Khushalani                             0
# Amod Sarnaik                                     0
# Lisa Diamond                                     0
# Susan Anitra Melin                               0
# Gary C. Doolittle                                0
# Ryan D. Gentzler                                 0
# Mary Helen Hackney                               0
# Jill N. Allen                                    0
# Sandip Pravin Patel                              0
# Philip Agop Philip                               0
# Jerome Ritz                                      0
# Rachel N. Grisham                                0
# William R. Jarnagin                              0
# Ellis Glenn Levine                               0
# Valerie Klairisa Reed                            0
# Abdulraheem Yacoub                               0
# Yanis Boumber                                    0
#
# [799 rows x 15 columns]

# %%
test_df.head()
# Out:
#                                   name           degree           phone  \
# name
# Kevin S. Hughes        Kevin S. Hughes         MD, FACS  (617) 724-0048
# Yu Chen                        Yu Chen          MD, PhD  (646) 422-4465
# Banu Arun                    Banu Arun        MD, FASCO  (713) 792-7090
# Naoto T. Ueno            Naoto T. Ueno          MD, PhD  (713) 792-8754
# Michael J. Hassett  Michael J. Hassett   MD, MPH, FASCO  (617) 632-4587
#
#                                                      center_name2  \
# name
# Kevin S. Hughes                    Massachusetts General Hospital
# Yu Chen                    Memorial Sloan Kettering Cancer Center
# Banu Arun           University of Texas MD Anderson Cancer Center
# Naoto T. Ueno       University of Texas MD Anderson Cancer Center
# Michael J. Hassett                   Dana-Farber Cancer Institute
#
#                                                      address  \
# name
# Kevin S. Hughes     Div of Surgcl Onc55 Fruit St Yawkey Bldg
# Yu Chen                                 1275 York Ave Box 20
# Banu Arun                                 1515 Holcombe blvd
# Naoto T. Ueno                    1515 Holcombe BlvdUnit 1354
# Michael J. Hassett                        450 Brookline Ave
#
#                                     city_state  \
# name
# Kevin S. Hughes           Boston, MA 02114, US
# Yu Chen                 New York, NY 10021, US
# Banu Arun                Houston, TX 77030, US
# Naoto T. Ueno       Houston, TX 77030-4000, US
# Michael J. Hassett        Boston, MA 02215, US
#
#                                                            speciality  \
# name
# Kevin S. Hughes            ['Breast Cancer', 'Genetics/Gene Therapy']
# Yu Chen                      ['Laboratory Research', 'Tumor Biology']
# Banu Arun                                           ['Breast Cancer']
# Naoto T. Ueno       ['Breast Cancer', 'Clinical Research', 'Develo...
# Michael J. Hassett      ['Breast Cancer', 'Health Services Research']
#
#                                                           certificate  \
# name
# Kevin S. Hughes                                 ['Surgical Oncology']
# Yu Chen                                          ['Medical Oncology']
# Banu Arun                          ['Hematology', 'Medical Oncology']
# Naoto T. Ueno               ['Internal Medicine', 'Medical Oncology']
# Michael J. Hassett  ['Hematology', 'Internal Medicine', 'Medical O...
#
#                                                           center_name  \
# name
# Kevin S. Hughes                        Massachusetts General Hospital
# Yu Chen                        Memorial Sloan-Kettering Cancer Center
# Banu Arun           The University of Texas MD Anderson Cancer Center
# Naoto T. Ueno       The University of Texas MD Anderson Cancer Center
# Michael J. Hassett                  Dana-Farber/Harvard Cancer Center
#
#                     article_num  clinical_trial_num  \
# name
# Kevin S. Hughes              84                   2
# Yu Chen                     558                  50
# Banu Arun                   181                   7
# Naoto T. Ueno               201                  13
# Michael J. Hassett           46                   0
#
#                                                            query_pmid  \
# name
# Kevin S. Hughes     [24748568, 29410346, 29785770, 17508275, 27160...
# Yu Chen             [27447970, 29169152, 25259624, 24276478, 26209...
# Banu Arun           [29044548, 18373644, 29733510, 16946209, 26017...
# Naoto T. Ueno       [29044548, 21607830, 30005774, 26017070, 22961...
# Michael J. Hassett  [21681446, 22235542, 22585699, 26868124, 21711...
#
#                     query_pmid_num  \
# name
# Kevin S. Hughes                 65
# Yu Chen                         70
# Banu Arun                      170
# Naoto T. Ueno                  163
# Michael J. Hassett              35
#
#                                                             pmid_rank  \
# name
# Kevin S. Hughes     [0, 28, 273, 327, 402, 431, 661, 672, 679, 847...
# Yu Chen             [1, 167, 524, 626, 630, 722, 927, 1119, 1121, ...
# Banu Arun           [2, 12, 56, 66, 69, 194, 221, 281, 289, 301, 3...
# Naoto T. Ueno       [2, 53, 68, 69, 211, 322, 331, 378, 410, 448, ...
# Michael J. Hassett  [3, 234, 391, 411, 414, 477, 557, 616, 668, 74...
#
#                     pmid_rank_10th_percentile
# name
# Kevin S. Hughes                             2
# Yu Chen                                     1
# Banu Arun                                   5
# Naoto T. Ueno                               4
# Michael J. Hassett                          1

# %%
test_df.sort_values(by=['pmid'])
# Out:
# name                                                        Charles L. Sawyers
# degree                                                                      MD
# phone                                                  Search for Phone Number
# center_name2                            Memorial Sloan Kettering Cancer Center
# address                                                    1275 York AveBox 20
# city_state                                              New York, NY 10065, US
# speciality                                                                  []
# certificate                  ['Hematology', 'Internal Medicine', 'Medical O...
# center_name                             Memorial Sloan-Kettering Cancer Center
# article_num                                                                146
# clinical_trial_num                                                           0
# query_pmid                   [29121144, 22641202, 17560336, 24027196, 19359...
# query_pmid_num                                                              70
# pmid_rank                    [26, 53, 72, 141, 203, 209, 234, 241, 264, 275...
# pmid_rank_10th_percentile                                                    1
# Name: Charles L. Sawyers, dtype: object

# %%
img_df=pd.read_csv(os.path.join(base_dir, "data/mskcc_img_dict_df.csv"),index_col='name')

# %%
onco_df[onco_df.center_name=='Abramson Cancer Center '].head()
# Out:
#                      name      degree                    phone  \
# 0           John H. Glick   MD, FASCO           (215) 662-6334
# 1       Arthur M. Feldman          MD           (215) 662-9801
# 2        David M. Mintzer          MD  Search for Phone Number
# 3         David J. Vaughn          MD           (215) 349-8140
# 4  Charles John Schneider    MD, FACP  Search for Phone Number
#
#                                         center_name2  \
# 0  University of Pennsylvania-Abramson Cancer Center
# 1  University of Pennsylvania-Abramson Cancer Center
# 2    Abramson Cancer Center at Pennsylvania Hospital
# 3  University of Pennsylvania-Abramson Cancer Center
# 4  Hospital of the University of Pennsylvania, Ab...
#
#                                              address  \
# 0           3400 Civic Center Blvd3rd Fl, Ste 3-300S
# 1  Penn Presbyterian Medcl Ctr51 N 39th St MAB St...
# 2                           230 W Washington Sq Fl 2
# 3            PCAM South 10-1143400 Civic Center Blvd
# 4  Pereleman Center for Advanced Medicine3400 Civ...
#
#                         city_state  \
# 0  Philadelphia, PA 19104-5127, US
# 1       Philadelphia, PA 19104, US
# 2  Philadelphia, PA 19106-3500, US
# 3       Philadelphia, PA 19104, US
# 4       Philadelphia, PA 19104, US
#
#                                           speciality  \
# 0             ['Breast Cancer', 'Cancer Prevention']
# 1           ['Breast Cancer', 'Geriatrics Oncology']
# 2  ['Breast Cancer', 'Lung Cancer', 'Palliative C...
# 3  ['Bladder Cancer', 'Prostate Cancer', 'Testicu...
# 4  ['Clinical Research', 'Developmental Therapeut...
#
#                                          certificate              center_name  \
# 0          ['Internal Medicine', 'Medical Oncology']  Abramson Cancer Center
# 1          ['Internal Medicine', 'Medical Oncology']  Abramson Cancer Center
# 2  ['Hematology', 'Hospice and Palliative Medicin...  Abramson Cancer Center
# 3                               ['Medical Oncology']  Abramson Cancer Center
# 4                               ['Medical Oncology']  Abramson Cancer Center
#
#    article_num  clinical_trial_num
# 0            7                   0
# 1            0                   1
# 2           13                   0
# 3           86                   1
# 4            0                   5

# %%
onco_df.center_name.nunique()
# Out:
# 48

# %%
from platform import python_version
print(python_version())
# Out:
# 3.6.2

# %%
abstract_df_aws=pd.read_csv(os.path.join(base_dir,'data/abstract_citation_annot_df_50930_aws.csv'))
abstract_df_aws.columns
# Out:
# Index(['article_title', 'journal_title', 'journal_abbre', 'article_date',
#        'abstract', 'pub_days', 'citation', 'abstract_clean', 'pmid'],
#       dtype='object')

# %%
abstract_df_aws=abstract_df_aws[['article_title', 'journal_title', 'journal_abbre', 'article_date', 'pub_days', 'citation', 'pmid']]

# %%
abstract_df_aws.to_csv(os.path.join(base_dir, 'data/abstract_citation_annot_df_50930_aws.csv'), index=False)

# %%
abstract_df_aws.shape
# Out:
# (50930, 7)

# %%
abstract_df_aws=pd.read_csv(os.path.join(base_dir, 'data/abstract_citation_annot_df_50930_aws.csv'))

# %%
abstract_df_aws.head()
# Out:
#                                        article_title  \
# 0        Pseudohypoproteinemia and multiple myeloma.
# 1  Comparison of digital rectal examination and s...
# 2  Accuracy of digital rectal examination and tra...
# 3  Selection of optimal prostate specific antigen...
# 4  Effect of patient age on early detection of pr...
#
#                           journal_title     journal_abbre article_date  \
# 0  Cleveland Clinic journal of medicine  Cleve Clin J Med   1990-05-01
# 1                The Journal of urology          J. Urol.   1994-05-01
# 2                The Journal of urology          J. Urol.   1994-11-01
# 3                The Journal of urology          J. Urol.   1994-12-01
# 4                               Urology           Urology   1993-10-01
#
#                                             abstract  pub_days  citation  \
# 0  Paraproteinemia is an important diagnostic fea...   10857.0       1.0
# 1  To compare the efficacy of digital rectal exam...    9396.0    1218.0
# 2  Not all prostate cancers are sonographically h...    9212.0     116.0
# 3  A prospective clinical trial of prostate cance...    9182.0     230.0
# 4  This study was designed to determine the effec...    9608.0     132.0
#
#                                       abstract_clean     pmid
# 0  Paraproteinemia is an important diagnostic fea...  2357786
# 1  To compare the efficacy of digital examination...  7512659
# 2  Not all cancers are sonographically hypoechoic...  7523707
# 3  A prospective clinical trial of cancer screeni...  7525995
# 4  This study was designed to determine the effec...  7692657

# %%
center_name=onco_df.center_name.unique()[22]
print(center_name)
"_".join([i.lower() for i in center_name.split()])
# Out:
# Sidney Kimmel Comprehensive Cancer Center
# 'sidney_kimmel_comprehensive_cancer_center'

# %%
similarity_df.shape
# Out:
# (8563, 2)

# %%
## Gene filtering
if gene_name != 'NA':
    pmid_gene=Get_info().gene_to_pmid(gene_name, gene_df)
    pmid_list=[]
    for i in similarity_df.pmid:
        if i in pmid_gene:
            pmid_list.append(i)
else:
    pmid_list=list(similarity_df.pmid)   ## 865

# %%
len(pmid_gene)
# Out:
# 865

# %%
## clinical trial filtering and get oncologist info
test_df = onco.get_onco_info(pmid_list,clinical_trial)   ## (95, 16)

# %%
test_df.shape
# Out:
# (95, 16)

# %%
test_df.head()
# Out:
#                                       name           degree  \
# name
# Banu Arun                        Banu Arun        MD, FASCO
# Mark E. Robson              Mark E. Robson        MD, FASCO
# Shridar Ganesan            Shridar Ganesan          MD, PhD
# Kenneth Offit                Kenneth Offit   MD, MPH, FASCO
# Funda Meric-Bernstam  Funda Meric-Bernstam               MD
#
#                                         phone  \
# name
# Banu Arun                      (713) 792-7090
# Mark E. Robson                 (646) 888-5434
# Shridar Ganesan       Search for Phone Number
# Kenneth Offit                  (646) 888-4067
# Funda Meric-Bernstam           (713) 794-1226
#
#                                                        center_name2  \
# name
# Banu Arun             University of Texas MD Anderson Cancer Center
# Mark E. Robson               Memorial Sloan Kettering Cancer Center
# Shridar Ganesan              Rutgers Cancer Institute of New Jersey
# Kenneth Offit                Memorial Sloan Kettering Cancer Center
# Funda Meric-Bernstam  University of Texas MD Anderson Cancer Center
#
#                                                    address  \
# name
# Banu Arun                               1515 Holcombe blvd
# Mark E. Robson        1275 York AveBreast Medicine Service
# Shridar Ganesan
# Kenneth Offit                1275 York AveInternal Box 192
# Funda Meric-Bernstam            1400 Holcombe BlvdUnit 455
#
#                                        city_state  \
# name
# Banu Arun                   Houston, TX 77030, US
# Mark E. Robson        New York, NY 10065-6007, US
# Shridar Ganesan       New Brunswick, NJ 08903, US
# Kenneth Offit         New York, NY 10065-6007, US
# Funda Meric-Bernstam        Houston, TX 77230, US
#
#                                                              speciality  \
# name
# Banu Arun                                             ['Breast Cancer']
# Mark E. Robson        ['Breast Cancer', 'Cancer Prevention', 'Geneti...
# Shridar Ganesan       ['Breast Cancer', 'Laboratory Research', 'Mole...
# Kenneth Offit                                         ['Tumor Biology']
# Funda Meric-Bernstam  ['Breast Cancer', 'Laboratory Research', 'Tumo...
#
#                                                     certificate  \
# name
# Banu Arun                    ['Hematology', 'Medical Oncology']
# Mark E. Robson               ['Hematology', 'Medical Oncology']
# Shridar Ganesan       ['Internal Medicine', 'Medical Oncology']
# Kenneth Offit                ['Hematology', 'Medical Oncology']
# Funda Meric-Bernstam                      ['Surgical Oncology']
#
#                                                             center_name  \
# name
# Banu Arun             The University of Texas MD Anderson Cancer Center
# Mark E. Robson                   Memorial Sloan-Kettering Cancer Center
# Shridar Ganesan                  Rutgers Cancer Institute of New Jersey
# Kenneth Offit                    Memorial Sloan-Kettering Cancer Center
# Funda Meric-Bernstam  The University of Texas MD Anderson Cancer Center
#
#                       article_num  clinical_trial_num  \
# name
# Banu Arun                     181                   7
# Mark E. Robson                 88                   2
# Shridar Ganesan                64                   2
# Kenneth Offit                 259                  14
# Funda Meric-Bernstam          337                   9
#
#                                                              query_pmid  \
# name
# Banu Arun             [19174581, 16421416, 24522996, 20609467, 16955...
# Mark E. Robson        [21598239, 20554149, 20221693, 30689033, 30181...
# Shridar Ganesan       [24478461, 17350581, 21278454, 23650262, 22331...
# Kenneth Offit         [21598239, 20221693, 18326623, 17916242, 23054...
# Funda Meric-Bernstam  [19174581, 29533782, 29093017, 24811890, 16955...
#
#                       query_pmid_num  \
# name
# Banu Arun                         68
# Mark E. Robson                    37
# Shridar Ganesan                   14
# Kenneth Offit                     92
# Funda Meric-Bernstam              17
#
#                                                               pmid_rank  \
# name
# Banu Arun             [5, 13, 17, 41, 72, 73, 83, 85, 88, 99, 115, 1...
# Mark E. Robson        [0, 7, 19, 50, 69, 75, 105, 123, 138, 153, 202...
# Shridar Ganesan       [6, 12, 22, 52, 76, 78, 80, 145, 241, 316, 338...
# Kenneth Offit         [0, 19, 21, 27, 87, 92, 99, 100, 102, 105, 117...
# Funda Meric-Bernstam  [5, 11, 44, 49, 72, 83, 91, 312, 319, 339, 420...
#
#                       pmid_rank_10th_percentile  clinical_trial_num2
# name
# Banu Arun                                     3                    7
# Mark E. Robson                                3                    1
# Shridar Ganesan                               2                    1
# Kenneth Offit                                 2                    4
# Funda Meric-Bernstam                          2                    6

# %%
test_df.loc[onco_name,'center_name']
# Out:
# 'Memorial Sloan-Kettering Cancer Center'

# %%
test_df.head()
# Out:
#                             name           degree                    phone  \
# name
# Kenneth Offit      Kenneth Offit   MD, MPH, FASCO           (646) 888-4067
# Claudine Isaacs  Claudine Isaacs               MD  Search for Phone Number
# Mark E. Robson    Mark E. Robson        MD, FASCO           (646) 888-5434
# Banu Arun              Banu Arun        MD, FASCO           (713) 792-7090
# Larry Norton        Larry Norton        MD, FASCO           (646) 888-5438
#
#                                                   center_name2  \
# name
# Kenneth Offit           Memorial Sloan Kettering Cancer Center
# Claudine Isaacs  Lombardi Cancer Center, Georgetown University
# Mark E. Robson          Memorial Sloan Kettering Cancer Center
# Banu Arun        University of Texas MD Anderson Cancer Center
# Larry Norton            Memorial Sloan Kettering Cancer Center
#
#                                               address  \
# name
# Kenneth Offit           1275 York AveInternal Box 192
# Claudine Isaacs                  3800 Reservoir Rd NW
# Mark E. Robson   1275 York AveBreast Medicine Service
# Banu Arun                          1515 Holcombe blvd
# Larry Norton                            1275 York Ave
#
#                                     city_state  \
# name
# Kenneth Offit      New York, NY 10065-6007, US
# Claudine Isaacs  Washington, DC 20007-2113, US
# Mark E. Robson     New York, NY 10065-6007, US
# Banu Arun                Houston, TX 77030, US
# Larry Norton            New York, NY 10065, US
#
#                                                         speciality  \
# name
# Kenneth Offit                                    ['Tumor Biology']
# Claudine Isaacs  ['Breast Cancer', 'Clinical Research', 'Geneti...
# Mark E. Robson   ['Breast Cancer', 'Cancer Prevention', 'Geneti...
# Banu Arun                                        ['Breast Cancer']
# Larry Norton                ['Breast Cancer', 'Clinical Research']
#
#                                                certificate  \
# name
# Kenneth Offit           ['Hematology', 'Medical Oncology']
# Claudine Isaacs  ['Internal Medicine', 'Medical Oncology']
# Mark E. Robson          ['Hematology', 'Medical Oncology']
# Banu Arun               ['Hematology', 'Medical Oncology']
# Larry Norton                          ['Medical Oncology']
#
#                                                        center_name  \
# name
# Kenneth Offit               Memorial Sloan-Kettering Cancer Center
# Claudine Isaacs    Georgetown Lombardi Comprehensive Cancer Center
# Mark E. Robson              Memorial Sloan-Kettering Cancer Center
# Banu Arun        The University of Texas MD Anderson Cancer Center
# Larry Norton                Memorial Sloan-Kettering Cancer Center
#
#                  article_num  clinical_trial_num  \
# name
# Kenneth Offit            259                  14
# Claudine Isaacs          185                   6
# Mark E. Robson            88                   2
# Banu Arun                181                   7
# Larry Norton             192                  25
#
#                                                         query_pmid  \
# name
# Kenneth Offit    [12464649, 14709740, 18268356, 21118973, 15131...
# Claudine Isaacs  [12464649, 15095307, 18268356, 21118973, 18195...
# Mark E. Robson   [28765325, 18268356, 15131025, 14680495, 12655...
# Banu Arun        [29044548, 29733510, 16946209, 18779615, 21656...
# Larry Norton     [28765325, 18268356, 14680495, 26011570, 12023...
#
#                  query_pmid_num  \
# name
# Kenneth Offit                92
# Claudine Isaacs              91
# Mark E. Robson               37
# Banu Arun                    68
# Larry Norton                 18
#
#                                                          pmid_rank  \
# name
# Kenneth Offit    [3, 8, 12, 13, 15, 17, 26, 48, 49, 52, 55, 65,...
# Claudine Isaacs  [3, 10, 12, 13, 16, 24, 25, 26, 35, 39, 43, 68...
# Mark E. Robson   [7, 12, 15, 17, 49, 52, 92, 94, 136, 157, 161,...
# Banu Arun        [0, 5, 6, 18, 27, 28, 29, 37, 53, 56, 66, 74, ...
# Larry Norton     [7, 12, 17, 79, 92, 123, 126, 180, 247, 257, 3...
#
#                  pmid_rank_10th_percentile  clinical_trial_num2
# name
# Kenneth Offit                            6                    4
# Claudine Isaacs                          5                    5
# Mark E. Robson                           4                    1
# Banu Arun                                4                    7
# Larry Norton                             3                    7

# %%
test_df.name.iloc[0]
# Out:
# 'Kenneth Offit'

# %%
test_df = pd.read_csv(os.path.join(base_dir,'temp/temp.csv'),index_col='name',converters={"query_pmid":literal_eval, "pmid_rank":literal_eval})
pmid_list=test_df.loc[onco_name,'query_pmid'][:test_df.loc[onco_name,'pmid_rank_10th_percentile']]

# %%
pmid_list
# Out:
# [12464649, 14709740, 18268356, 21118973, 15131025, 14680495]

# %%
onco_name='Kenneth Offit'
pmid_list = test_df.loc[onco_name,'query_pmid'][:test_df.loc[onco_name,'pmid_rank_10th_percentile']]

# %%
pmid_df=abstract_catalog.loc[np.array(pmid_list)]
pmid_df.head()
# Out:
#                                               article_title  \
# pmid
# 12464649  Oral contraceptives and the risk of breast can...
# 14709740  Frequency of BRCA1 and BRCA2 mutations in unse...
# 18268356  Risk-reducing salpingo-oophorectomy for the pr...
# 21118973  Common breast cancer susceptibility alleles an...
# 15131025  BRCA mutations and risk of prostate cancer in ...
#
#                                               journal_title  \
# pmid
# 12464649           Journal of the National Cancer Institute
# 14709740           Journal of the National Cancer Institute
# 18268356  Journal of clinical oncology : official journa...
# 21118973                                    Cancer research
# 15131025  Clinical cancer research : an official journal...
#
#                   journal_abbre article_date  \
# pmid
# 12464649  J. Natl. Cancer Inst.   2002-12-01
# 14709740  J. Natl. Cancer Inst.   2004-01-01
# 18268356        J. Clin. Oncol.   2008-02-11
# 21118973            Cancer Res.   2010-11-30
# 15131025      Clin. Cancer Res.   2004-05-01
#
#                                                    abstract  \
# pmid
# 12464649  Oral contraceptive use has been associated wit...
# 14709740  Mutations in BRCA1 and BRCA2 that predispose t...
# 18268356  Risk-reducing salpingo-oophorectomy (RRSO) has...
# 21118973  The known breast cancer susceptibility polymor...
# 15131025  The Breast Cancer Linkage Consortium and other...
#
#                article_type  pub_days  citation  \
# pmid
# 12464649    Journal Article    6260.0     289.0
# 14709740    Journal Article    5864.0      51.0
# 18268356    Journal Article    4362.0     401.0
# 21118973    Journal Article    3339.0       NaN
# 15131025  Comparative Study    5743.0     111.0
#
#                                              abstract_clean  Breast Cancer  \
# pmid
# 12464649  Oral contraceptive use has been associated wit...              1
# 14709740  Mutations in BRCA1 and BRCA2 that predispose t...              1
# 18268356  Risk-reducing salpingo-oophorectomy RRSO has b...              1
# 21118973  The known cancer susceptibility polymorphisms ...              1
# 15131025  The Cancer Linkage Consortium and other family...              1
#
#           ...  Endometrial Cancer  Acute Lymphoblastic Leukemia (ALL)  \
# pmid      ...
# 12464649  ...                   0                                   0
# 14709740  ...                   0                                   0
# 18268356  ...                   0                                   0
# 21118973  ...                   0                                   0
# 15131025  ...                   0                                   0
#
#           Chronic Lymphocytic Leukemia (CLL)  Cardiac Tumors  Cervical Cancer  \
# pmid
# 12464649                                   0               0                0
# 14709740                                   0               0                0
# 18268356                                   0               0                0
# 21118973                                   0               0                0
# 15131025                                   0               0                0
#
#           Esophageal Cancer  Thyroid Cancer  Rectal Cancer  \
# pmid
# 12464649                  0               0              0
# 14709740                  0               0              0
# 18268356                  0               0              0
# 21118973                  0               0              0
# 15131025                  0               0              0
#
#                                              text_clean_seq  text_length
# pmid
# 12464649  [518, 6780, 119, 71, 85, 41, 5, 35, 344, 4, 3,...       1836.0
# 14709740  [138, 4, 766, 2, 1167, 17, 6043, 6, 2, 12, 32,...       1001.0
# 18268356  [43, 1818, 5690, 3470, 7376, 71, 85, 1792, 445...       1667.0
# 21118973  [3, 440, 12, 1432, 1203, 4, 5273, 22426, 19887...       1691.0
# 15131025  [3, 12, 4820, 2404, 2, 127, 607, 90, 54147, 47...       1429.0
#
# [5 rows x 40 columns]

# %%
onco_name='Kenneth Offit'
onco_clinical_df = onco.get_clinical_data(onco_name)

# %%
onco_clinical_df.head()
# Out:
#            NCTId           name  \
# 684  NCT00579514  Kenneth Offit
# 685  NCT00579488  Kenneth Offit
# 686  NCT00590109  Kenneth Offit
#
#                                             BriefTitle           Phase  \
# 684  Germline Alterations of Tumor Susceptibility G...  Not Applicable
# 685   Clinical Significance of Germline BRCA Mutations             NaN
# 686  Germline BRCA1 and BRCA2 Mutations in Jewish W...             NaN
#
#                                              Condition    cancer_type
# 684  Breast Cancer, Bladder Cancer, Kidney Cancer, ...  Breast Cancer
# 685                      Breast Cancer, Ovarian Cancer  Breast Cancer
# 686                                      Breast Cancer  Breast Cancer

# %%
onco_clinical_df.shape
# Out:
# (3, 6)

# %%
onco_df.head()
# Out:
#                      name      degree                    phone  \
# 0           John H. Glick   MD, FASCO           (215) 662-6334
# 1       Arthur M. Feldman          MD           (215) 662-9801
# 2        David M. Mintzer          MD  Search for Phone Number
# 3         David J. Vaughn          MD           (215) 349-8140
# 4  Charles John Schneider    MD, FACP  Search for Phone Number
#
#                                         center_name2  \
# 0  University of Pennsylvania-Abramson Cancer Center
# 1  University of Pennsylvania-Abramson Cancer Center
# 2    Abramson Cancer Center at Pennsylvania Hospital
# 3  University of Pennsylvania-Abramson Cancer Center
# 4  Hospital of the University of Pennsylvania, Ab...
#
#                                              address  \
# 0           3400 Civic Center Blvd3rd Fl, Ste 3-300S
# 1  Penn Presbyterian Medcl Ctr51 N 39th St MAB St...
# 2                           230 W Washington Sq Fl 2
# 3            PCAM South 10-1143400 Civic Center Blvd
# 4  Pereleman Center for Advanced Medicine3400 Civ...
#
#                         city_state  \
# 0  Philadelphia, PA 19104-5127, US
# 1       Philadelphia, PA 19104, US
# 2  Philadelphia, PA 19106-3500, US
# 3       Philadelphia, PA 19104, US
# 4       Philadelphia, PA 19104, US
#
#                                           speciality  \
# 0             ['Breast Cancer', 'Cancer Prevention']
# 1           ['Breast Cancer', 'Geriatrics Oncology']
# 2  ['Breast Cancer', 'Lung Cancer', 'Palliative C...
# 3  ['Bladder Cancer', 'Prostate Cancer', 'Testicu...
# 4  ['Clinical Research', 'Developmental Therapeut...
#
#                                          certificate              center_name  \
# 0          ['Internal Medicine', 'Medical Oncology']  Abramson Cancer Center
# 1          ['Internal Medicine', 'Medical Oncology']  Abramson Cancer Center
# 2  ['Hematology', 'Hospice and Palliative Medicin...  Abramson Cancer Center
# 3                               ['Medical Oncology']  Abramson Cancer Center
# 4                               ['Medical Oncology']  Abramson Cancer Center
#
#    article_num  clinical_trial_num
# 0            7                   0
# 1            0                   1
# 2           13                   0
# 3           86                   1
# 4            0                   5

# %%
print(test_df.shape)
test_df.head()
# Out:
# (181, 15)
#                             name          degree                    phone  \
# name
# Banu Arun              Banu Arun       MD, FASCO           (713) 792-7090
# Naoto T. Ueno      Naoto T. Ueno         MD, PhD           (713) 792-8754
# Saundra S. Buys  Saundra S. Buys              MD  Search for Phone Number
# Charis Eng            Charis Eng   MD, PhD, FACP           (216) 444-3440
# Claudine Isaacs  Claudine Isaacs              MD  Search for Phone Number
#
#                                                       center_name2  \
# name
# Banu Arun            University of Texas MD Anderson Cancer Center
# Naoto T. Ueno        University of Texas MD Anderson Cancer Center
# Saundra S. Buys  Huntsman Cancer Institute - University of Utah...
# Charis Eng                             Cleveland Clinic Foundation
# Claudine Isaacs      Lombardi Cancer Center, Georgetown University
#
#                                                            address  \
# name
# Banu Arun                                       1515 Holcombe blvd
# Naoto T. Ueno                          1515 Holcombe BlvdUnit 1354
# Saundra S. Buys                             2000 Circle of Hope Dr
# Charis Eng       Cleveland Clin Genomic Med Inst9500 Euclid Ave...
# Claudine Isaacs                               3800 Reservoir Rd NW
#
#                                         city_state  \
# name
# Banu Arun                    Houston, TX 77030, US
# Naoto T. Ueno           Houston, TX 77030-4000, US
# Saundra S. Buys  Salt Lake City, UT 84112-5550, US
# Charis Eng                 Cleveland, OH 44195, US
# Claudine Isaacs      Washington, DC 20007-2113, US
#
#                                                         speciality  \
# name
# Banu Arun                                        ['Breast Cancer']
# Naoto T. Ueno    ['Breast Cancer', 'Clinical Research', 'Develo...
# Saundra S. Buys         ['Breast Cancer', 'Genetics/Gene Therapy']
# Charis Eng       ['Breast Cancer', 'Endocrine Tumors', 'Genetic...
# Claudine Isaacs  ['Breast Cancer', 'Clinical Research', 'Geneti...
#
#                                                        certificate  \
# name
# Banu Arun                       ['Hematology', 'Medical Oncology']
# Naoto T. Ueno            ['Internal Medicine', 'Medical Oncology']
# Saundra S. Buys                 ['Hematology', 'Medical Oncology']
# Charis Eng       ['Internal Medicine', 'Medical Oncology', 'Oth...
# Claudine Isaacs          ['Internal Medicine', 'Medical Oncology']
#
#                                                        center_name  \
# name
# Banu Arun        The University of Texas MD Anderson Cancer Center
# Naoto T. Ueno    The University of Texas MD Anderson Cancer Center
# Saundra S. Buys                          Huntsman Cancer Institute
# Charis Eng                                        Cleveland Clinic
# Claudine Isaacs    Georgetown Lombardi Comprehensive Cancer Center
#
#                  article_num  clinical_trial_num  \
# name
# Banu Arun                181                   7
# Naoto T. Ueno            201                  13
# Saundra S. Buys          125                   4
# Charis Eng               300                   1
# Claudine Isaacs          185                   6
#
#                                                         query_pmid  \
# name
# Banu Arun        [29044548, 29733510, 16946209, 18779615, 21656...
# Naoto T. Ueno                                 [29044548, 27135926]
# Saundra S. Buys  [18704680, 17021353, 21118973, 19188678, 11792...
# Charis Eng       [23740344, 24458845, 29684080, 16563180, 16032...
# Claudine Isaacs  [12464649, 15095307, 18268356, 21118973, 18195...
#
#                  query_pmid_num  \
# name
# Banu Arun                    68
# Naoto T. Ueno                 2
# Saundra S. Buys              52
# Charis Eng                   20
# Claudine Isaacs              91
#
#                                                          pmid_rank  \
# name
# Banu Arun        [0, 5, 6, 18, 27, 28, 29, 37, 53, 56, 66, 74, ...
# Naoto T. Ueno                                             [0, 555]
# Saundra S. Buys  [1, 4, 13, 38, 41, 89, 95, 113, 117, 127, 134,...
# Charis Eng       [2, 20, 140, 166, 196, 201, 208, 217, 236, 241...
# Claudine Isaacs  [3, 10, 12, 13, 16, 24, 25, 26, 35, 39, 43, 68...
#
#                  pmid_rank_10th_percentile
# name
# Banu Arun                                4
# Naoto T. Ueno                            1
# Saundra S. Buys                          3
# Charis Eng                               1
# Claudine Isaacs                          5

# %%
test_df=pd.read_csv(os.path.join(base_dir,'temp/temp.csv'))

# %%
test_df.head()
# Out:
#               name           degree                    phone  \
# 0    Kenneth Offit   MD, MPH, FASCO           (646) 888-4067
# 1  Claudine Isaacs               MD  Search for Phone Number
# 2   Mark E. Robson        MD, FASCO           (646) 888-5434
# 3        Banu Arun        MD, FASCO           (713) 792-7090
# 4     Larry Norton        MD, FASCO           (646) 888-5438
#
#                                     center_name2  \
# 0         Memorial Sloan Kettering Cancer Center
# 1  Lombardi Cancer Center, Georgetown University
# 2         Memorial Sloan Kettering Cancer Center
# 3  University of Texas MD Anderson Cancer Center
# 4         Memorial Sloan Kettering Cancer Center
#
#                                 address                     city_state  \
# 0         1275 York AveInternal Box 192    New York, NY 10065-6007, US
# 1                  3800 Reservoir Rd NW  Washington, DC 20007-2113, US
# 2  1275 York AveBreast Medicine Service    New York, NY 10065-6007, US
# 3                    1515 Holcombe blvd          Houston, TX 77030, US
# 4                         1275 York Ave         New York, NY 10065, US
#
#                                           speciality  \
# 0                                  ['Tumor Biology']
# 1  ['Breast Cancer', 'Clinical Research', 'Geneti...
# 2  ['Breast Cancer', 'Cancer Prevention', 'Geneti...
# 3                                  ['Breast Cancer']
# 4             ['Breast Cancer', 'Clinical Research']
#
#                                  certificate  \
# 0         ['Hematology', 'Medical Oncology']
# 1  ['Internal Medicine', 'Medical Oncology']
# 2         ['Hematology', 'Medical Oncology']
# 3         ['Hematology', 'Medical Oncology']
# 4                       ['Medical Oncology']
#
#                                          center_name  article_num  \
# 0             Memorial Sloan-Kettering Cancer Center          259
# 1    Georgetown Lombardi Comprehensive Cancer Center          185
# 2             Memorial Sloan-Kettering Cancer Center           88
# 3  The University of Texas MD Anderson Cancer Center          181
# 4             Memorial Sloan-Kettering Cancer Center          192
#
#    clinical_trial_num                                         query_pmid  \
# 0                  14  [12464649, 14709740, 18268356, 21118973, 15131...
# 1                   6  [12464649, 15095307, 18268356, 21118973, 18195...
# 2                   2  [28765325, 18268356, 15131025, 14680495, 12655...
# 3                   7  [29044548, 29733510, 16946209, 18779615, 21656...
# 4                  25  [28765325, 18268356, 14680495, 26011570, 12023...
#
#    query_pmid_num                                          pmid_rank  \
# 0              92  [3, 8, 12, 13, 15, 17, 26, 48, 49, 52, 55, 65,...
# 1              91  [3, 10, 12, 13, 16, 24, 25, 26, 35, 39, 43, 68...
# 2              37  [7, 12, 15, 17, 49, 52, 92, 94, 136, 157, 161,...
# 3              68  [0, 5, 6, 18, 27, 28, 29, 37, 53, 56, 66, 74, ...
# 4              18  [7, 12, 17, 79, 92, 123, 126, 180, 247, 257, 3...
#
#    pmid_rank_10th_percentile  clinical_trial_num2
# 0                          6                    4
# 1                          5                    5
# 2                          4                    1
# 3                          4                    7
# 4                          3                    7

# %%
test_df.shape
# Out:
# (95, 16)

# %%
test_df.head()
# Out:
#                             name           degree                    phone  \
# name
# Kenneth Offit      Kenneth Offit   MD, MPH, FASCO           (646) 888-4067
# Claudine Isaacs  Claudine Isaacs               MD  Search for Phone Number
# Mark E. Robson    Mark E. Robson        MD, FASCO           (646) 888-5434
# Banu Arun              Banu Arun        MD, FASCO           (713) 792-7090
# Larry Norton        Larry Norton        MD, FASCO           (646) 888-5438
#
#                                                   center_name2  \
# name
# Kenneth Offit           Memorial Sloan Kettering Cancer Center
# Claudine Isaacs  Lombardi Cancer Center, Georgetown University
# Mark E. Robson          Memorial Sloan Kettering Cancer Center
# Banu Arun        University of Texas MD Anderson Cancer Center
# Larry Norton            Memorial Sloan Kettering Cancer Center
#
#                                               address  \
# name
# Kenneth Offit           1275 York AveInternal Box 192
# Claudine Isaacs                  3800 Reservoir Rd NW
# Mark E. Robson   1275 York AveBreast Medicine Service
# Banu Arun                          1515 Holcombe blvd
# Larry Norton                            1275 York Ave
#
#                                     city_state  \
# name
# Kenneth Offit      New York, NY 10065-6007, US
# Claudine Isaacs  Washington, DC 20007-2113, US
# Mark E. Robson     New York, NY 10065-6007, US
# Banu Arun                Houston, TX 77030, US
# Larry Norton            New York, NY 10065, US
#
#                                                         speciality  \
# name
# Kenneth Offit                                    ['Tumor Biology']
# Claudine Isaacs  ['Breast Cancer', 'Clinical Research', 'Geneti...
# Mark E. Robson   ['Breast Cancer', 'Cancer Prevention', 'Geneti...
# Banu Arun                                        ['Breast Cancer']
# Larry Norton                ['Breast Cancer', 'Clinical Research']
#
#                                                certificate  \
# name
# Kenneth Offit           ['Hematology', 'Medical Oncology']
# Claudine Isaacs  ['Internal Medicine', 'Medical Oncology']
# Mark E. Robson          ['Hematology', 'Medical Oncology']
# Banu Arun               ['Hematology', 'Medical Oncology']
# Larry Norton                          ['Medical Oncology']
#
#                                                        center_name  \
# name
# Kenneth Offit               Memorial Sloan-Kettering Cancer Center
# Claudine Isaacs    Georgetown Lombardi Comprehensive Cancer Center
# Mark E. Robson              Memorial Sloan-Kettering Cancer Center
# Banu Arun        The University of Texas MD Anderson Cancer Center
# Larry Norton                Memorial Sloan-Kettering Cancer Center
#
#                  article_num  clinical_trial_num  \
# name
# Kenneth Offit            259                  14
# Claudine Isaacs          185                   6
# Mark E. Robson            88                   2
# Banu Arun                181                   7
# Larry Norton             192                  25
#
#                                                         query_pmid  \
# name
# Kenneth Offit    [12464649, 14709740, 18268356, 21118973, 15131...
# Claudine Isaacs  [12464649, 15095307, 18268356, 21118973, 18195...
# Mark E. Robson   [28765325, 18268356, 15131025, 14680495, 12655...
# Banu Arun        [29044548, 29733510, 16946209, 18779615, 21656...
# Larry Norton     [28765325, 18268356, 14680495, 26011570, 12023...
#
#                  query_pmid_num  \
# name
# Kenneth Offit                92
# Claudine Isaacs              91
# Mark E. Robson               37
# Banu Arun                    68
# Larry Norton                 18
#
#                                                          pmid_rank  \
# name
# Kenneth Offit    [3, 8, 12, 13, 15, 17, 26, 48, 49, 52, 55, 65,...
# Claudine Isaacs  [3, 10, 12, 13, 16, 24, 25, 26, 35, 39, 43, 68...
# Mark E. Robson   [7, 12, 15, 17, 49, 52, 92, 94, 136, 157, 161,...
# Banu Arun        [0, 5, 6, 18, 27, 28, 29, 37, 53, 56, 66, 74, ...
# Larry Norton     [7, 12, 17, 79, 92, 123, 126, 180, 247, 257, 3...
#
#                  pmid_rank_10th_percentile  clinical_trial_Breast Cancer_num
# name
# Kenneth Offit                            6                                 4
# Claudine Isaacs                          5                                 5
# Mark E. Robson                           4                                 1
# Banu Arun                                4                                 7
# Larry Norton                             3                                 7

# %%
test_df = get_onco_info('Breast Cancer', breast_pmid,clinical_trial=True)
test_df.shape
test_df.head()
# Out:
#                                         name            degree  \
# name
# Kelly Hunt                        Kelly Hunt                MD
# Gabriel N. Hortobagyi  Gabriel N. Hortobagyi   MD, FACP, FASCO
# Larry Norton                    Larry Norton         MD, FASCO
# Vicente Valero                Vicente Valero                MD
# Nuhad K. Ibrahim            Nuhad K. Ibrahim                MD
#
#                                          phone  \
# name
# Kelly Hunt             Search for Phone Number
# Gabriel N. Hortobagyi           (713) 792-4124
# Larry Norton                    (646) 888-5438
# Vicente Valero                  (713) 792-4124
# Nuhad K. Ibrahim                (713) 792-2817
#
#                                                         center_name2  \
# name
# Kelly Hunt             University of Texas MD Anderson Cancer Center
# Gabriel N. Hortobagyi  University of Texas MD Anderson Cancer Center
# Larry Norton                  Memorial Sloan Kettering Cancer Center
# Vicente Valero         University of Texas MD Anderson Cancer Center
# Nuhad K. Ibrahim       University of Texas MD Anderson Cancer Center
#
#                                                                  address  \
# name
# Kelly Hunt             Dept of Surgical Oncology - Unit 444P. O. Box ...
# Gabriel N. Hortobagyi                             Unit 1354PO Box 301439
# Larry Norton                                               1275 York Ave
# Vicente Valero                                             PO Box 301439
# Nuhad K. Ibrahim                               1515 Holcombe Blvd # 1354
#
#                                        city_state  \
# name
# Kelly Hunt             Houston, TX 77230-1402, US
# Gabriel N. Hortobagyi  Houston, TX 77230-1439, US
# Larry Norton               New York, NY 10065, US
# Vicente Valero         Houston, TX 77230-1439, US
# Nuhad K. Ibrahim           Houston, TX 77030-4000
#
#                                                               speciality  \
# name
# Kelly Hunt             ['Breast Cancer', 'Sarcoma', 'Clinical Trials/...
# Gabriel N. Hortobagyi  ['Breast Cancer', 'Cancer Education', 'Drug De...
# Larry Norton                      ['Breast Cancer', 'Clinical Research']
# Vicente Valero         ['Breast Cancer', 'Clinical Trials/Biostatisti...
# Nuhad K. Ibrahim       ['Breast Cancer', 'Clinical Trials/Biostatisti...
#
#                                                              certificate  \
# name
# Kelly Hunt                                         ['Surgical Oncology']
# Gabriel N. Hortobagyi          ['Internal Medicine', 'Medical Oncology']
# Larry Norton                                        ['Medical Oncology']
# Vicente Valero         ['Hematology', 'Internal Medicine', 'Medical O...
# Nuhad K. Ibrahim               ['Internal Medicine', 'Medical Oncology']
#
#                                                              center_name  \
# name
# Kelly Hunt             The University of Texas MD Anderson Cancer Center
# Gabriel N. Hortobagyi  The University of Texas MD Anderson Cancer Center
# Larry Norton                      Memorial Sloan-Kettering Cancer Center
# Vicente Valero         The University of Texas MD Anderson Cancer Center
# Nuhad K. Ibrahim       The University of Texas MD Anderson Cancer Center
#
#                        article_num  clinical_trial_num  \
# name
# Kelly Hunt                     469                   3
# Gabriel N. Hortobagyi          569                   1
# Larry Norton                   192                  25
# Vicente Valero                 239                   5
# Nuhad K. Ibrahim                45                   2
#
#                                                               query_pmid  \
# name
# Kelly Hunt             [11773149, 11800340, 11884322, 11923128, 11923...
# Gabriel N. Hortobagyi  [11773149, 11839684, 11844821, 11852999, 11856...
# Larry Norton           [11821455, 11821456, 11870168, 11901151, 11981...
# Vicente Valero         [11852999, 11914909, 11919237, 12006521, 12015...
# Nuhad K. Ibrahim       [11852999, 12006521, 12429622, 12429628, 12620...
#
#                        query_pmid_num  \
# name
# Kelly Hunt                        347
# Gabriel N. Hortobagyi             506
# Larry Norton                      158
# Vicente Valero                    212
# Nuhad K. Ibrahim                   41
#
#                                                                pmid_rank  \
# name
# Kelly Hunt             [0, 5, 30, 47, 49, 72, 73, 76, 109, 120, 122, ...
# Gabriel N. Hortobagyi  [0, 13, 14, 18, 20, 41, 43, 76, 82, 94, 96, 10...
# Larry Norton           [10, 11, 24, 37, 66, 85, 165, 313, 323, 335, 3...
# Vicente Valero         [18, 41, 43, 76, 82, 94, 96, 120, 129, 130, 14...
# Nuhad K. Ibrahim       [18, 76, 213, 214, 305, 371, 737, 866, 1014, 1...
#
#                        pmid_rank_10th_percentile  \
# name
# Kelly Hunt                                     8
# Gabriel N. Hortobagyi                          8
# Larry Norton                                   5
# Vicente Valero                                 4
# Nuhad K. Ibrahim                               2
#
#                        clinical_trial_Breast Cancer_num
# name
# Kelly Hunt                                            3
# Gabriel N. Hortobagyi                                 1
# Larry Norton                                          7
# Vicente Valero                                        5
# Nuhad K. Ibrahim                                      2

# %%
cancerclinical2doctor_dict=pickle.load(open(os.path.join(base_dir, "data/cancerclinical2doctor_dict.pkl"),"rb"))
clinical_trial=True
if clinical_trial and cancer_type in cancerclinical2doctor_dict:
    doctor_clin = cancerclinical2doctor_dict[cancer_type]

# %%
test_df2 = test_df.loc[np.array(doctor_clin)].sort_values(by=['rank_pmid'])
doctor2clinical_dict2=pickle.load(open(os.path.join(base_dir, "data/doctor2clinical_dict2.pkl"),"rb"))
test_df2['clinical_trial_{}_num'.format(cancer_type)]=test_df2.name.apply(lambda x: doctor2clinical_dict2[x][cancer_type])
test_df2.head()
# Out:
#                                         name            degree  \
# name
# Gabriel N. Hortobagyi  Gabriel N. Hortobagyi   MD, FACP, FASCO
# Kelly Hunt                        Kelly Hunt                MD
# Eddy J. Chen                    Eddy J. Chen                MD
# Claudine Isaacs              Claudine Isaacs                MD
# Saundra S. Buys              Saundra S. Buys                MD
#
#                                          phone  \
# name
# Gabriel N. Hortobagyi           (713) 792-4124
# Kelly Hunt             Search for Phone Number
# Eddy J. Chen                    (978) 287-3436
# Claudine Isaacs        Search for Phone Number
# Saundra S. Buys        Search for Phone Number
#
#                                                             center_name2  \
# name
# Gabriel N. Hortobagyi      University of Texas MD Anderson Cancer Center
# Kelly Hunt                 University of Texas MD Anderson Cancer Center
# Eddy J. Chen                Massachusetts General Hospital Cancer Center
# Claudine Isaacs            Lombardi Cancer Center, Georgetown University
# Saundra S. Buys        Huntsman Cancer Institute - University of Utah...
#
#                                                                  address  \
# name
# Gabriel N. Hortobagyi                             Unit 1354PO Box 301439
# Kelly Hunt             Dept of Surgical Oncology - Unit 444P. O. Box ...
# Eddy J. Chen                                55 Fruit StMgh Cancer Center
# Claudine Isaacs                                     3800 Reservoir Rd NW
# Saundra S. Buys                                   2000 Circle of Hope Dr
#
#                                               city_state  \
# name
# Gabriel N. Hortobagyi         Houston, TX 77230-1439, US
# Kelly Hunt                    Houston, TX 77230-1402, US
# Eddy J. Chen                   Boston, MA 02114-2621, US
# Claudine Isaacs            Washington, DC 20007-2113, US
# Saundra S. Buys        Salt Lake City, UT 84112-5550, US
#
#                                                               speciality  \
# name
# Gabriel N. Hortobagyi  ['Breast Cancer', 'Cancer Education', 'Drug De...
# Kelly Hunt             ['Breast Cancer', 'Sarcoma', 'Clinical Trials/...
# Eddy J. Chen           ['Bladder Cancer', 'Kidney Cancer', 'Medical O...
# Claudine Isaacs        ['Breast Cancer', 'Clinical Research', 'Geneti...
# Saundra S. Buys               ['Breast Cancer', 'Genetics/Gene Therapy']
#
#                                                              certificate  \
# name
# Gabriel N. Hortobagyi          ['Internal Medicine', 'Medical Oncology']
# Kelly Hunt                                         ['Surgical Oncology']
# Eddy J. Chen           ['Hematology', 'Internal Medicine', 'Medical O...
# Claudine Isaacs                ['Internal Medicine', 'Medical Oncology']
# Saundra S. Buys                       ['Hematology', 'Medical Oncology']
#
#                                                              center_name  \
# name
# Gabriel N. Hortobagyi  The University of Texas MD Anderson Cancer Center
# Kelly Hunt             The University of Texas MD Anderson Cancer Center
# Eddy J. Chen                              Massachusetts General Hospital
# Claudine Isaacs          Georgetown Lombardi Comprehensive Cancer Center
# Saundra S. Buys                                Huntsman Cancer Institute
#
#                        article_num  clinical_trial_num  \
# name
# Gabriel N. Hortobagyi          569                   1
# Kelly Hunt                     469                   3
# Eddy J. Chen                     3                   3
# Claudine Isaacs                185                   6
# Saundra S. Buys                125                   4
#
#                                                               query_pmid  \
# name
# Gabriel N. Hortobagyi  [11773149, 11839684, 11844821, 11852999, 11856...
# Kelly Hunt             [11773149, 11800340, 11884322, 11923128, 11923...
# Eddy J. Chen                                                  [11782367]
# Claudine Isaacs        [11786581, 11881908, 12023993, 12376518, 12464...
# Saundra S. Buys        [11792833, 15217505, 16600944, 16626501, 16896...
#
#                        query_pmid_num  rank_pmid  \
# name
# Gabriel N. Hortobagyi             506          0
# Kelly Hunt                        347          1
# Eddy J. Chen                        1          2
# Claudine Isaacs                   161          3
# Saundra S. Buys                    96          5
#
#                        clinical_trial_Breast Cancer_num
# name
# Gabriel N. Hortobagyi                                 1
# Kelly Hunt                                            3
# Eddy J. Chen                                          2
# Claudine Isaacs                                       5
# Saundra S. Buys                                       4

# %%
test_df2.shape
# Out:
# (280, 13)

# %%
doctor2clinical_dict2=pickle.load(open(os.path.join(base_dir, "data/doctor2clinical_dict2.pkl"),"rb"))

# %%
doctor2clinical_dict2['Gabriel N. Hortobagyi']['Breast Cancer']
# Out:
# Counter({'Breast Cancer': 1})

# %%
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        temp=WordNetLemmatizer().lemmatize(token).lower()
        if len(temp)>1 and temp not in stop_words:
            result.append(temp)
    return result

# %%
gene_name = 'BCR'

# %%
def get_pmid_for_gene(gene,data=gene_df):
    pmid_array = data.query('HGNC=="{}"'.format(gene)).pmid.unique()
    # pmid_array[~pd.isnull(pmid_array)]
    return pmid_array

# %%
pmid_gene = get_pmid_for_gene(gene_name,data=gene_df)

#        24723681, 24729196, 24731026, 24753251, 24778152, 24779033,
#        24794806, 24891015, 24942980, 24944159, 24978359, 24981688,
#        24984571, 24997151, 25001469, 25012565, 25049322, 25049327,
#        25099443, 25132497, 25134459, 25141832, 25185093, 25207766,
#        25255165, 25258342, 25281405, 25293770, 25294696, 25294898,
#        25301179, 25301759, 25331939, 25356603, 25361806, 25361807,
#        25387837, 25465126, 25495177, 25528388, 25555325, 25586015,
#        25682168, 25712988, 25814091, 25833959, 25840461, 25841721,
#        25858358, 25867648, 25882987, 25887498, 25903013, 25921387,
#        25971713, 25997600, 26022051, 26040495, 26096907, 26166626,
#        26190356, 26208445, 26217876, 26231323, 26231860, 26238810,
#        26243778, 26252865, 26308885, 26341038, 26358140, 26431162,
#        26432046, 26434969, 26436130, 26436949, 26455714, 26479889,
#        26537529, 26566171, 26580245, 26585806, 26603185, 26603839,
#        26615132, 26620454, 26637730, 26687797, 26688093, 26717038,
#        26729897, 26743563, 26769227, 26776345, 26796981, 26799612,
#        26846160, 26892479, 26944912, 26964698, 26986977, 27006386,
#        27017614, 27133948, 27144331, 27217448, 27229714, 27235138,
#        27287425, 27377901, 27509035, 27521332, 27531525, 27533462,
#        27534555, 27605552, 27624943, 27626693, 27658269, 27660167,
#        27763690, 27927766, 27956535, 28147336, 28167659, 28230003,
#        28253536, 28273028, 28293819, 28352655, 28387926, 28388280,
#        28464280, 28486040, 28495918, 28596283, 28619981, 28681664,
#        28722170, 28743165, 28749919, 28835371, 28835440, 28927784,
#        28971501, 28972424, 28972430, 29027261, 29050692, 29072772,
#        29113986, 29119847, 29158516, 29199525, 29222233, 29230008,
#        29242398, 29246803, 29251676, 29252123, 29263420, 29266206,
#        29301866, 29386193, 29411417, 29446205, 29449681, 29463446,
#        29464484, 29465264, 29498925, 29505034, 29567798, 29609532,
#        29687320, 29695515, 29723397, 29741794, 29742077, 29784750,
#        29843123, 29853276, 29931220, 29951914, 30071761, 30074634,
#        30080238, 30093506, 30153491, 30181422, 30209121, 30231323,
#        30318751, 30321462, 30357754, 30396912, 30413649, 30487223,
#        30501869, 30508305, 30530780, 30587215, 30617194, 30630577,
#        30830579, 30831480, 31158102, 31208943, 31826340,  9306419])

# %%
similarity_df.head()
# Out:
#           lda_similarity
# pmid
# 27836010        0.999982
# 24412296        0.999965
# 19800463        0.999942
# 28535000        0.999940
# 25605296        0.999940

# %%
pmid_list=[]
for i in similarity_df.index:
    if i in pmid_gene:
        pmid_list.append(i)

# %%
len(pmid_list)
# Out:
# 12

# %% [markdown]
# ### Validation LDA models using text description

# %%
mskcc_text_df=pd.read_csv(os.path.join(base_dir, 'data/mskcc_text_dict_df.csv'),index_col='name')
mskcc_text_df.head()
# Out:
#                                                                  text
# name
# Kenneth H. Yu       I am a medical oncologist with expertise in th...
# Robert Sidlow       I am a board-certified general internist and p...
# Lisa Marie Ruppert  I am a physician of Physical Medicine and Reha...
# Yukio Sonoda        I am a gynecologic oncologist who performs abo...
# Marsha Reyngold     I am a board-certified radiation oncologist wh...
